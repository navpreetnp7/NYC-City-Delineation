# %%
import time
import argparse
import numpy as np

import torch
import torch.optim as optim

import torch.nn as nn

from utils import load_data,normalize,toy_data
from models import GNN

from networkx import from_numpy_matrix
import networkx as nx

from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module

import pycombo

import pandas as pd

torch.set_printoptions(sci_mode=False)

from utils import doublerelu

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
cuda = torch.cuda.is_available()
weight_decay = 10e-4
epochs = 1000
seed = 165

# %%
np.random.seed(seed)
torch.manual_seed(seed)
if cuda:
    torch.cuda.manual_seed(seed)

# %%
class GNN1Layer(Module):

    def __init__(self, batch_size, in_features, out_features):
        super(GNN1Layer, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.batch_size = batch_size

        weight1_eye = torch.FloatTensor(torch.eye(in_features, out_features))
        weight1_eye = weight1_eye.reshape((1, in_features, out_features))
        weight1_eye = weight1_eye.repeat(batch_size, 1, 1)
        self.weight1 = Parameter(weight1_eye)
        self.weight2 = Parameter(torch.zeros(batch_size, in_features, out_features))

    def forward(self, input, adj):
        v1 = torch.bmm(input, self.weight1)
        v2 = torch.bmm(torch.bmm(adj, input), self.weight2)
        output = v1 + v2
        return output

# %%
class GNN2Layer(Module):

    def __init__(self, batch_size, in_features, out_features):
        super(GNN2Layer, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.batch_size = batch_size
        weight1_eye = torch.FloatTensor(torch.eye(in_features, out_features))
        weight1_eye = weight1_eye.reshape((1, in_features, out_features))
        weight1_eye = weight1_eye.repeat(batch_size, 1, 1)
        weight1_rand = torch.empty(batch_size,in_features,out_features-in_features)
        torch.nn.init.xavier_uniform_(weight1_rand, gain=1.0)
        self.weight1 = Parameter(weight1_eye)
        self.weight2 = Parameter(torch.zeros(batch_size, in_features, out_features))

    def forward(self, input, adj):
        v1 = torch.bmm(input, self.weight1)
        v2 = torch.bmm(torch.bmm(adj, input), self.weight2)
        output = v1 + v2
        return output

# %%
class GNN1(nn.Module):

    def __init__(self, batch_size, nfeat, ndim, hidden):
        super(GNN1, self).__init__()

        self.gc1 = GNN1Layer(batch_size, ndim, ndim)

    def forward(self, x, adj):
        x = doublerelu(self.gc1(x, adj))
        x = x/x.sum(axis=2).unsqueeze(2) #normalize st sum = 1
        return x

# %%
class GNN2(nn.Module):

    def __init__(self, batch_size, nfeat, ndim, hidden):
        super(GNN2, self).__init__()

        self.gc1 = GNN2Layer(batch_size, ndim, hidden)
        self.gc2 = GNN1Layer(batch_size, hidden, ndim)

    def forward(self, x, adj):
        x = doublerelu(self.gc1(x, adj))
        x = doublerelu(self.gc2(x, adj))
        x = x/x.sum(axis=2).unsqueeze(2) #normalize st sum = 1
        return x

# %%
def community_detection(G,method,GNN,features=None,hidden=1):
    
    adj = nx.to_numpy_matrix(G)
    adj = np.expand_dims(adj, axis=0)
        
    #Combo
    combo_partition = pycombo.execute(G)
    nb_comm = max(combo_partition[0].values())+1
    combo_mod = combo_partition[1]

    adj_norm = normalize(adj)

    adj = torch.FloatTensor(np.array(adj))
    adj_norm = torch.FloatTensor(np.array(adj_norm))
    
    partition = community_louvain.best_partition(G)
    #get binary matrix of the partition
    nb_community = max(list(partition.values())) + 1
        
    if type(features) == type(None):

        # features
        if method == "louvain":
            partition = community_louvain.best_partition(G)
            #get binary matrix of the partition
            nb_community = max(list(partition.values())) + 1
            communities =  np.array(list(partition.values())).reshape(-1)
            C = np.eye(nb_community)[communities]
            C = torch.FloatTensor(C)
            #perturbations
            C = perturb(C)
        elif method == "spectral":
            partition = spectralPartition(adj,nb_comm)
            C = partition.float()
            nb_community = C.shape[1]

        features = torch.FloatTensor(C)
        features = features.unsqueeze(0)
    
    if method == "louvain":
        lr = 0.001
    elif method == "spectral":
        lr = 0.001
        

    Q = modularity_matrix(adj)
    
    # Model and optimizer

    model = GNN(batch_size=adj.shape[0],
                nfeat=adj.shape[1],
                ndim=nb_community,
                hidden=hidden)

    if cuda:
        model.cuda()
        features = features.cuda()
        adj = adj.cuda()
        adj_norm = adj_norm.cuda()
        Q = Q.cuda()

    # Train model
    t_total = time.time()

    optimizer = optim.Adam(model.parameters(),
                           lr=lr, weight_decay=weight_decay)
    

    for epoch in range(epochs):

        t = time.time()
        model.train()
        optimizer.zero_grad()

        C = model(features, adj_norm)
        loss = modularity(C,Q)

        loss.backward(retain_graph=True)

        optimizer.step()

        if epoch == 0:
            best_loss = loss
            init_mod = loss
            best_C = C
        else:
            if loss < best_loss:
                best_loss = loss
                best_C = C

        if epoch % 100 == 0:
            print('Epoch: {:04d}'.format(epoch + 1),
                  'Modularity: {:.8f}'.format(-best_loss.item()),
                  'time: {:.4f}s'.format(time.time() - t))

    print("Optimization Finished!")
    print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
    
    return nb_community,-init_mod,-best_loss,combo_mod, best_C

# %%
def perturb(A):
    p = 0.4
    epsilon = torch.rand(A.shape).uniform_(0, p) - torch.rand(A.shape).uniform_(0, p)
    return torch.clip(A + epsilon,0,1)

# %%
def spectralPartition(A,nb_comm):
    A = A[0] # TODO 3D
    clustering = SpectralClustering(n_clusters=nb_comm,assign_labels='discretize',random_state=0).fit(A)
    clusters = list(clustering.labels_)
    partitions = torch.tensor(clusters)
    return torch.nn.functional.one_hot(partitions)

# %%
def exp(hidden):
    G = [nx.karate_club_graph(),nx.les_miserables_graph(),nx.florentine_families_graph()]
    methods = ["louvain","spectral"]
    nb_communities = []
    init_mods = []
    finetuned_mods = []
    combo_mods = []
    methodss = []
    networks = ["Karate Club","Karate Club","Les Miserables","Les Miserables","Florentine","Florentine"]
    for network in G:
        for method in methods:
            nb_community,init_mod,finetuned_mod,combo_mod,features = community_detection(network,method,GNN1,hidden=1)
            nb_community,init_mod,finetuned_mod,combo_mod,features = community_detection(network,method,GNN2,features=features,hidden=nb_community+4)
            nb_communities.append(nb_community)
            init_mods.append(init_mod.cpu().detach().numpy()[0][0])
            finetuned_mods.append(finetuned_mod.cpu().detach().numpy()[0][0])
            combo_mods.append(combo_mod)
            methodss.append(method)
    df = pd.DataFrame([networks,methodss,nb_communities,hidden,init_mods,finetuned_mods,combo_mods]).transpose()
    df.columns = ["Network","Method","Communities","Hidden Dimensionality","Initial Modularity","Finetuned Moduclarity","Combo Modularity"] 
    return df
# Out:
# Epoch: 0001 Modularity: 0.24411677 time: 0.5338s
# Epoch: 0101 Modularity: 0.40143764 time: 0.0000s
# Epoch: 0201 Modularity: 0.41847557 time: 0.0000s
# Epoch: 0301 Modularity: 0.41975754 time: 0.0156s
# Epoch: 0401 Modularity: 0.41978747 time: 0.0000s
# Epoch: 0501 Modularity: 0.41978961 time: 0.0000s
# Epoch: 0601 Modularity: 0.41978961 time: 0.0000s
# Epoch: 0701 Modularity: 0.41978961 time: 0.0000s
# Epoch: 0801 Modularity: 0.41978961 time: 0.0000s
# Epoch: 0901 Modularity: 0.41978961 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 3.0920s
# Epoch: 0001 Modularity: 0.41978961 time: 0.0156s
# Epoch: 0101 Modularity: 0.41978961 time: 0.0095s
# Epoch: 0201 Modularity: 0.41978961 time: 0.0000s
# Epoch: 0301 Modularity: 0.41978961 time: 0.0156s
# Epoch: 0401 Modularity: 0.41978961 time: 0.0000s
# Epoch: 0501 Modularity: 0.41978961 time: 0.0167s
# Epoch: 0601 Modularity: 0.41978961 time: 0.0000s
# Epoch: 0701 Modularity: 0.41978961 time: 0.0000s
# Epoch: 0801 Modularity: 0.41978961 time: 0.0000s
# Epoch: 0901 Modularity: 0.41978961 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 4.3002s
# Epoch: 0001 Modularity: 0.34015450 time: 0.0156s
# Epoch: 0101 Modularity: 0.35263938 time: 0.0000s
# Epoch: 0201 Modularity: 0.35894844 time: 0.0000s
# Epoch: 0301 Modularity: 0.36297059 time: 0.0000s
# Epoch: 0401 Modularity: 0.36976776 time: 0.0000s
# Epoch: 0501 Modularity: 0.39869636 time: 0.0000s
# Epoch: 0601 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0701 Modularity: 0.39907956 time: 0.0156s
# Epoch: 0801 Modularity: 0.39907956 time: 0.0156s
# Epoch: 0901 Modularity: 0.39907956 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 2.2734s
# Epoch: 0001 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0101 Modularity: 0.39907956 time: 0.0040s
# Epoch: 0201 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0301 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0401 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0501 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0601 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0701 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0801 Modularity: 0.39907956 time: 0.0000s
# Epoch: 0901 Modularity: 0.39907956 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 4.2368s
# Epoch: 0001 Modularity: 0.27444220 time: 0.0000s
# Epoch: 0101 Modularity: 0.53215927 time: 0.0000s
# Epoch: 0201 Modularity: 0.56496346 time: 0.0000s
# Epoch: 0301 Modularity: 0.56565535 time: 0.0000s
# Epoch: 0401 Modularity: 0.56595057 time: 0.0000s
# Epoch: 0501 Modularity: 0.56628174 time: 0.0000s
# Epoch: 0601 Modularity: 0.56658530 time: 0.0000s
# Epoch: 0701 Modularity: 0.56668800 time: 0.0000s
# Epoch: 0801 Modularity: 0.56668800 time: 0.0000s
# Epoch: 0901 Modularity: 0.56668800 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 2.3868s
# Epoch: 0001 Modularity: 0.56668800 time: 0.0000s
# Epoch: 0101 Modularity: 0.56668800 time: 0.0000s
# Epoch: 0201 Modularity: 0.56668800 time: 0.0000s
# Epoch: 0301 Modularity: 0.56668800 time: 0.0000s
# Epoch: 0401 Modularity: 0.56668800 time: 0.0000s
# Epoch: 0501 Modularity: 0.56668800 time: 0.0156s
# Epoch: 0601 Modularity: 0.56668800 time: 0.0000s
# Epoch: 0701 Modularity: 0.56668800 time: 0.0156s
# Epoch: 0801 Modularity: 0.56668800 time: 0.0000s
# Epoch: 0901 Modularity: 0.56668800 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 3.9068s
# Epoch: 0001 Modularity: 0.11745612 time: 0.0000s
# Epoch: 0101 Modularity: 0.14251940 time: 0.0000s
# Epoch: 0201 Modularity: 0.17311493 time: 0.0000s
# Epoch: 0301 Modularity: 0.23827371 time: 0.0025s
# Epoch: 0401 Modularity: 0.39308828 time: 0.0000s
# Epoch: 0501 Modularity: 0.39308828 time: 0.0000s
# Epoch: 0601 Modularity: 0.39308828 time: 0.0000s
# Epoch: 0701 Modularity: 0.39308828 time: 0.0000s
# Epoch: 0801 Modularity: 0.39308828 time: 0.0000s
# Epoch: 0901 Modularity: 0.39308828 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 2.3065s
# Epoch: 0001 Modularity: 0.39308828 time: 0.0000s
# Epoch: 0101 Modularity: 0.42326027 time: 0.0156s
# Epoch: 0201 Modularity: 0.43598980 time: 0.0000s
# Epoch: 0301 Modularity: 0.45294198 time: 0.0000s
# Epoch: 0401 Modularity: 0.47407562 time: 0.0000s
# Epoch: 0501 Modularity: 0.47725797 time: 0.0000s
# Epoch: 0601 Modularity: 0.47725797 time: 0.0000s
# Epoch: 0701 Modularity: 0.47725797 time: 0.0156s
# Epoch: 0801 Modularity: 0.47725797 time: 0.0000s
# Epoch: 0901 Modularity: 0.47725797 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 4.5644s
# Epoch: 0001 Modularity: 0.27611637 time: 0.0156s
# Epoch: 0101 Modularity: 0.39650327 time: 0.0000s
# Epoch: 0201 Modularity: 0.39750004 time: 0.0000s
# Epoch: 0301 Modularity: 0.39750004 time: 0.0130s
# Epoch: 0401 Modularity: 0.39750004 time: 0.0000s
# Epoch: 0501 Modularity: 0.39750004 time: 0.0000s
# Epoch: 0601 Modularity: 0.39750004 time: 0.0000s
# Epoch: 0701 Modularity: 0.39750004 time: 0.0156s
# Epoch: 0801 Modularity: 0.39750004 time: 0.0000s
# Epoch: 0901 Modularity: 0.39750004 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 2.2907s
# Epoch: 0001 Modularity: 0.39750004 time: 0.0156s
# Epoch: 0101 Modularity: 0.39750004 time: 0.0000s
# Epoch: 0201 Modularity: 0.39750004 time: 0.0000s
# Epoch: 0301 Modularity: 0.39750004 time: 0.0000s
# Epoch: 0401 Modularity: 0.39750004 time: 0.0000s
# Epoch: 0501 Modularity: 0.39750004 time: 0.0000s
# Epoch: 0601 Modularity: 0.39750004 time: 0.0000s
# Epoch: 0701 Modularity: 0.39750004 time: 0.0000s
# Epoch: 0801 Modularity: 0.39750004 time: 0.0000s
# Epoch: 0901 Modularity: 0.39750004 time: 0.0156s
# Optimization Finished!
# Total time elapsed: 4.1266s
# Epoch: 0001 Modularity: -0.17124999 time: 0.0045s
# Epoch: 0101 Modularity: -0.04291525 time: 0.0000s
# Epoch: 0201 Modularity: 0.03025404 time: 0.0000s
# Epoch: 0301 Modularity: 0.13500090 time: 0.0000s
# Epoch: 0401 Modularity: 0.21293184 time: 0.0000s
# Epoch: 0501 Modularity: 0.21866006 time: 0.0000s
# Epoch: 0601 Modularity: 0.22078627 time: 0.0000s
# Epoch: 0701 Modularity: 0.22193506 time: 0.0000s
# Epoch: 0801 Modularity: 0.22437158 time: 0.0000s
# Epoch: 0901 Modularity: 0.24251574 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 2.3262s
# Epoch: 0001 Modularity: 0.29674834 time: 0.0000s
# Epoch: 0101 Modularity: 0.29739088 time: 0.0000s
# Epoch: 0201 Modularity: 0.29802099 time: 0.0000s
# Epoch: 0301 Modularity: 0.29857868 time: 0.0000s
# Epoch: 0401 Modularity: 0.29900873 time: 0.0156s
# Epoch: 0501 Modularity: 0.29943922 time: 0.0000s
# Epoch: 0601 Modularity: 0.29967850 time: 0.0145s
# Epoch: 0701 Modularity: 0.29967850 time: 0.0000s
# Epoch: 0801 Modularity: 0.29967850 time: 0.0000s
# Epoch: 0901 Modularity: 0.29967850 time: 0.0156s
# Optimization Finished!
# Total time elapsed: 4.0922s
# Epoch: 0001 Modularity: 0.10608065 time: 0.0000s
# Epoch: 0101 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0201 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0301 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0401 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0501 Modularity: 0.11111113 time: 0.0156s
# Epoch: 0601 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0701 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0801 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0901 Modularity: 0.11111113 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 2.1812s
# Epoch: 0001 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0101 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0201 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0301 Modularity: 0.11111113 time: 0.0156s
# Epoch: 0401 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0501 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0601 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0701 Modularity: 0.11111113 time: 0.0156s
# Epoch: 0801 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0901 Modularity: 0.11111113 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 4.2235s
# Epoch: 0001 Modularity: -0.34722221 time: 0.0000s
# Epoch: 0101 Modularity: -0.16593158 time: 0.0000s
# Epoch: 0201 Modularity: -0.08554590 time: 0.0156s
# Epoch: 0301 Modularity: -0.04279959 time: 0.0156s
# Epoch: 0401 Modularity: -0.01909548 time: 0.0156s
# Epoch: 0501 Modularity: -0.00689262 time: 0.0000s
# Epoch: 0601 Modularity: -0.00176898 time: 0.0000s
# Epoch: 0701 Modularity: -0.00022246 time: 0.0000s
# Epoch: 0801 Modularity: 0.00009126 time: 0.0000s
# Epoch: 0901 Modularity: 0.00013704 time: 0.0150s
# Optimization Finished!
# Total time elapsed: 2.8573s
# Epoch: 0001 Modularity: 0.00014605 time: 0.0000s
# Epoch: 0101 Modularity: 0.00267122 time: 0.0000s
# Epoch: 0201 Modularity: 0.11111113 time: 0.0156s
# Epoch: 0301 Modularity: 0.11111113 time: 0.0040s
# Epoch: 0401 Modularity: 0.11111113 time: 0.0173s
# Epoch: 0501 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0601 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0701 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0801 Modularity: 0.11111113 time: 0.0000s
# Epoch: 0901 Modularity: 0.11111113 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 5.3028s

# %%
for hidden in range(3,11):
    print(exp(hidden))
# Out:
#           Network    Method Communities Initial Modularity  \
# 0     Karate Club   louvain           4           0.419790
# 1     Karate Club  spectral           4           0.399080
# 2  Les Miserables   louvain           6           0.566688
# 3  Les Miserables  spectral           6           0.393088
# 4      Florentine   louvain           4           0.397500
# 5      Florentine  spectral           3           0.296748
# 6     House Graph   louvain           2           0.111111
# 7     House Graph  spectral           2           0.000146
#
#   Finetuned Moduclarity Combo Modularity
# 0              0.419790         0.419790
# 1              0.399080         0.419790
# 2              0.566688         0.566688
# 3              0.477258         0.566688
# 4              0.397500         0.398750
# 5              0.299679         0.398750
# 6              0.111111         0.111111
# 7              0.111111         0.111111
