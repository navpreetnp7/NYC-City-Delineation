# %%
import networkx as nx
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module
torch.set_printoptions(sci_mode=False)
import time

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('data/zips_merged.csv', delimiter=',')
data = data.rename(columns={'total': 'weight', 'w_zip':'origin', 'h_zip':'destination'})
data = data[data.destination.isin(data.origin.unique())]
data.head()
# Out:
#    origin  destination  weight  initialFeat  true_label
# 0   11436        10009       1          4.0           4
# 1   11436        10011       1          4.0           4
# 2   11436        10013       1          4.0           4
# 3   11436        10019       1          4.0           4
# 4   11436        10021       1          4.0           4

# %%
cuda = torch.cuda.is_available()
weight_decay = 10e-4
epochs = 10001
seed = 165
hidden = 10
lr = 0.0001

# %%
np.random.seed(seed)
torch.manual_seed(seed)
if cuda:
    torch.cuda.manual_seed(seed)

# %%
def normalize(adj):

    adj = torch.FloatTensor(adj)
    adj_id = torch.FloatTensor(torch.eye(adj.shape[1]))
    adj_id = adj_id.reshape((1, adj.shape[1], adj.shape[1]))
    adj_id = adj_id.repeat(adj.shape[0], 1, 1)
    adj = adj + adj_id
    rowsum = torch.FloatTensor(adj.sum(2))
    degree_mat_inv_sqrt = torch.diag_embed(torch.float_power(rowsum,-0.5), dim1=-2, dim2=-1).float()
    adj_norm = torch.bmm(torch.transpose(torch.bmm(adj,degree_mat_inv_sqrt),1,2),degree_mat_inv_sqrt)

    return adj_norm


def doublerelu(x):
    return torch.clamp(x, 0, 1)

class GNN1Layer(Module):

    def __init__(self, batch_size, in_features, out_features, first):
        super(GNN1Layer, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.batch_size = batch_size

        weight1_eye = torch.FloatTensor(torch.eye(in_features, out_features))
        weight1_eye = weight1_eye.reshape((1, in_features, out_features))
        weight1_eye = weight1_eye.repeat(batch_size, 1, 1)
        self.weight1 = Parameter(weight1_eye)
        if not first:
            self.weight2 = Parameter(torch.zeros(batch_size, in_features, out_features))
        else:
            self.weight2 = Parameter(torch.empty(batch_size, in_features, out_features))
            nn.init.kaiming_normal_(self.weight2, mode='fan_out')

    def forward(self, input, adj):
        v1 = torch.bmm(input, self.weight1)
        v2 = torch.bmm(torch.bmm(adj, input), self.weight2)
        output = v1 + v2
        return output

# %%
class GNN1(nn.Module):

    def __init__(self, batch_size, nfeat, ndim, hidden, first):
        super(GNN1, self).__init__()

        self.gc1 = GNN1Layer(batch_size, nfeat, ndim, first)

    def forward(self, x, adj, random_indices):
        f = torch.clone(x)
        x = doublerelu(self.gc1(x, adj))
        x = x/x.sum(axis=2).unsqueeze(2) #normalize st sum = 1

        f[0][random_indices, :x.shape[2]] = x[0][random_indices, :]
        
        return f[:,:,:x.shape[2]]

# %%
def train(adj,features,labels,random_indices,first=False):
    
    adj_norm = normalize(adj)
    
    labels = labels - 1
    
    adj = torch.FloatTensor(adj)
    adj_norm = torch.FloatTensor(adj_norm)
    features = torch.FloatTensor(features)
    labels = torch.FloatTensor(labels)
    

    
    model = GNN1(batch_size=adj.shape[0],
                nfeat=features.shape[-1],
                ndim=nb_label,
                hidden=hidden,
                first=first)
    if cuda:
        model.cuda()
        features = features.cuda()
        adj = adj.cuda()
        adj_norm = adj_norm.cuda()
        labels = labels.cuda()
    
    # Train model
    t_total = time.time()

    optimizer = optim.Adam(model.parameters(),
                           lr=lr, weight_decay=weight_decay)
    
    criterion = nn.CrossEntropyLoss()
    
    for epoch in range(epochs):

        t = time.time()
        model.train()
        optimizer.zero_grad()

        output = model(features, adj_norm, random_indices)
            
        accuracy = torch.sum(torch.argmax(output,axis=2)==labels.reshape(1,-1))/labels.shape[0]
        
        loss = criterion(output[0],labels.reshape(-1).long())

        loss.backward(retain_graph=True)

        optimizer.step()

        if epoch == 0:
            best_loss = loss
            best_output = output
            best_acc = accuracy
        else:
            if loss < best_loss:
                best_loss = loss
                best_output = output
                best_acc = accuracy

        if epoch % 1000 == 0:
            print('Epoch: {:04d}'.format(epoch + 1),
                  'Accuracy: {:.4f}'.format(best_acc.item()),
                  'Loss: {:.8f}'.format(best_loss.item()),
                  'time: {:.4f}s'.format(time.time() - t))
            
    print("Optimization Finished!")
    print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
    
    return best_loss,best_output

# %%
def svdApprox(adj, dim, relu=False):
    adj = torch.FloatTensor(adj[0])
    U, S, Vh = torch.linalg.svd(adj)
    mu = torch.matmul(torch.matmul(U[:, :dim], torch.diag(S[:dim])), Vh[:dim, :])

    embedx = torch.matmul(U[:, :dim], torch.diag(torch.pow(S[:dim], 0.5)))
    embedy = torch.transpose(torch.matmul(torch.diag(torch.pow(S[:dim], 0.5)), Vh[:dim, :]), 0, 1)

    return embedx, embedy

# %%
def load_data():

    data = pd.read_csv('data/zips_merged.csv', delimiter=',')
    data = data.rename(columns={'total': 'weight', 'w_zip':'origin', 'h_zip':'destination'})
    data = data[data.destination.isin(data.origin.unique())]
    G = nx.from_pandas_edgelist(data, 'origin', 'destination', 'weight',create_using=nx.DiGraph())
    adj_list = np.array([nx.adjacency_matrix(G).todense()], dtype=float)
    init_feat = np.array(data.groupby('origin')['initialFeat'].agg(['unique']))
    true_label = np.array(data.groupby('origin')['true_label'].agg(['unique']))
    init_feat = np.array(list(map(lambda x: x[0], init_feat))).reshape(-1, 1)
    true_label = np.array(list(map(lambda x: x[0][0], true_label))).reshape(-1, 1)
    return adj_list,init_feat,true_label

adj,feature,labels = load_data()

feature = feature - 1
nb_label = int(max(feature)) + 1
featuress = np.eye(nb_label)[np.array(feature,dtype=int).reshape(1,-1)]

# %%
mask_percentage = [1.]

for m in mask_percentage:
    
    features = np.copy(featuress)
    
    
    # Masking
    number_of_rows = features[0].shape[0]
    random_indices = np.random.choice(number_of_rows, size=int(m*number_of_rows), replace=False)
    
    # exclude low activity areas from masking
    zip_sum = data.groupby(by='origin', as_index=False).sum()
    low_act = zip_sum[zip_sum.weight < 3000].index
    
    random_indices = np.setdiff1d(random_indices, low_act)
    random_rows = features[0][random_indices, :]
    features[0][random_indices, :] = np.tile(np.array([[0.2]]),random_rows.shape)
    
    
    print("\nMasked {}% of nodes\n".format(int(m*100)))
    prev_loss, op = train(adj,features,labels, random_indices, True)
    #print(op)
    loss, op = train(adj,op.cpu().detach().numpy(),labels, random_indices)
    while loss < prev_loss :
        prev_loss = loss
        loss, op = train(adj,op.cpu().detach().numpy(),labels, random_indices)
# Out:
# Masked 100% of nodes
#
# Epoch: 0001 Accuracy: 0.2885 Loss: 1.51545537 time: 0.8836s
# Epoch: 1001 Accuracy: 0.3846 Loss: 1.49089026 time: 0.0000s
# Epoch: 2001 Accuracy: 0.4038 Loss: 1.46659768 time: 0.0040s
# Epoch: 3001 Accuracy: 0.4087 Loss: 1.46186626 time: 0.0040s
# Epoch: 4001 Accuracy: 0.3990 Loss: 1.46016014 time: 0.0040s
# Epoch: 5001 Accuracy: 0.3894 Loss: 1.45841777 time: 0.0000s
# Epoch: 6001 Accuracy: 0.3894 Loss: 1.45544374 time: 0.0000s
# Epoch: 7001 Accuracy: 0.4135 Loss: 1.45003057 time: 0.0000s
# Epoch: 8001 Accuracy: 0.4135 Loss: 1.45003057 time: 0.0040s
# Epoch: 9001 Accuracy: 0.4135 Loss: 1.45003057 time: 0.0000s
# Epoch: 10001 Accuracy: 0.4135 Loss: 1.45003057 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 21.7156s
# Epoch: 0001 Accuracy: 0.4135 Loss: 1.45003057 time: 0.0040s
# Epoch: 1001 Accuracy: 0.4904 Loss: 1.37493682 time: 0.0000s
# Epoch: 2001 Accuracy: 0.5385 Loss: 1.36530566 time: 0.0040s
# Epoch: 3001 Accuracy: 0.5433 Loss: 1.36166894 time: 0.0000s
# Epoch: 4001 Accuracy: 0.5433 Loss: 1.35768425 time: 0.0000s
# Epoch: 5001 Accuracy: 0.5529 Loss: 1.35009122 time: 0.0000s
# Epoch: 6001 Accuracy: 0.5433 Loss: 1.32917523 time: 0.0040s
# Epoch: 7001 Accuracy: 0.5865 Loss: 1.30324113 time: 0.0040s
# Epoch: 8001 Accuracy: 0.5865 Loss: 1.30324113 time: 0.0040s
# Epoch: 9001 Accuracy: 0.5865 Loss: 1.30324113 time: 0.0040s
# Epoch: 10001 Accuracy: 0.5865 Loss: 1.30324113 time: 0.0040s
# Optimization Finished!
# Total time elapsed: 22.0922s
# Epoch: 0001 Accuracy: 0.5865 Loss: 1.30324113 time: 0.0040s
# Epoch: 1001 Accuracy: 0.5865 Loss: 1.29270220 time: 0.0040s
# Epoch: 2001 Accuracy: 0.6250 Loss: 1.27813315 time: 0.0040s
# Epoch: 3001 Accuracy: 0.6442 Loss: 1.26183200 time: 0.0000s
# Epoch: 4001 Accuracy: 0.6442 Loss: 1.26183200 time: 0.0000s
# Epoch: 5001 Accuracy: 0.6442 Loss: 1.26183200 time: 0.0040s
# Epoch: 6001 Accuracy: 0.6442 Loss: 1.26183200 time: 0.0000s
# Epoch: 7001 Accuracy: 0.6442 Loss: 1.26183200 time: 0.0000s
# Epoch: 8001 Accuracy: 0.6442 Loss: 1.26183200 time: 0.0040s
# Epoch: 9001 Accuracy: 0.6442 Loss: 1.26183200 time: 0.0000s
# Epoch: 10001 Accuracy: 0.6442 Loss: 1.26183200 time: 0.0040s
# Optimization Finished!
# Total time elapsed: 18.6197s
# Epoch: 0001 Accuracy: 0.6442 Loss: 1.26183200 time: 0.0000s
# Epoch: 1001 Accuracy: 0.6394 Loss: 1.25710869 time: 0.0030s
# Epoch: 2001 Accuracy: 0.6538 Loss: 1.25098526 time: 0.0030s
# Epoch: 3001 Accuracy: 0.6683 Loss: 1.23978305 time: 0.0040s
# Epoch: 4001 Accuracy: 0.6683 Loss: 1.23978305 time: 0.0040s
# Epoch: 5001 Accuracy: 0.6683 Loss: 1.23978305 time: 0.0000s
# Epoch: 6001 Accuracy: 0.6683 Loss: 1.23978305 time: 0.0040s
# Epoch: 7001 Accuracy: 0.6683 Loss: 1.23978305 time: 0.0040s
# Epoch: 8001 Accuracy: 0.6683 Loss: 1.23978305 time: 0.0000s
# Epoch: 9001 Accuracy: 0.6683 Loss: 1.23978305 time: 0.0040s
# Epoch: 10001 Accuracy: 0.6683 Loss: 1.23978305 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 20.8166s
# Epoch: 0001 Accuracy: 0.6683 Loss: 1.23978305 time: 0.0040s
# Epoch: 1001 Accuracy: 0.6683 Loss: 1.23447239 time: 0.0040s
# Epoch: 2001 Accuracy: 0.6683 Loss: 1.22839975 time: 0.0040s
# Epoch: 3001 Accuracy: 0.6683 Loss: 1.22438765 time: 0.0000s
# Epoch: 4001 Accuracy: 0.6683 Loss: 1.22285819 time: 0.0040s
# Epoch: 5001 Accuracy: 0.6683 Loss: 1.22285819 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6683 Loss: 1.22285819 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6683 Loss: 1.22285819 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6683 Loss: 1.22285819 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6683 Loss: 1.22285819 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6683 Loss: 1.22285819 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 21.1763s
# Epoch: 0001 Accuracy: 0.6683 Loss: 1.22285819 time: 0.0030s
# Epoch: 1001 Accuracy: 0.6683 Loss: 1.22122777 time: 0.0022s
# Epoch: 2001 Accuracy: 0.6779 Loss: 1.21929181 time: 0.0040s
# Epoch: 3001 Accuracy: 0.6875 Loss: 1.21716905 time: 0.0000s
# Epoch: 4001 Accuracy: 0.6875 Loss: 1.21571887 time: 0.0030s
# Epoch: 5001 Accuracy: 0.6875 Loss: 1.21571887 time: 0.0000s
# Epoch: 6001 Accuracy: 0.6875 Loss: 1.21571887 time: 0.0040s
# Epoch: 7001 Accuracy: 0.6875 Loss: 1.21571887 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6875 Loss: 1.21571887 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6875 Loss: 1.21571887 time: 0.0010s
# Epoch: 10001 Accuracy: 0.6875 Loss: 1.21571887 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 21.4429s
# Epoch: 0001 Accuracy: 0.6875 Loss: 1.21571887 time: 0.0030s
# Epoch: 1001 Accuracy: 0.6875 Loss: 1.21437871 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6923 Loss: 1.21233988 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.21065080 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.20923793 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.20923793 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.20923793 time: 0.0030s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.20923793 time: 0.0040s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.20923793 time: 0.0040s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.20923793 time: 0.0000s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.20923793 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 21.7820s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.20923793 time: 0.0000s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.20874047 time: 0.0000s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.20781982 time: 0.0040s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.20687175 time: 0.0040s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.20590973 time: 0.0000s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.20494032 time: 0.0040s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.20276272 time: 0.0000s
# Epoch: 7001 Accuracy: 0.7115 Loss: 1.19826245 time: 0.0000s
# Epoch: 8001 Accuracy: 0.7115 Loss: 1.19705892 time: 0.0040s
# Epoch: 9001 Accuracy: 0.7115 Loss: 1.19705892 time: 0.0040s
# Epoch: 10001 Accuracy: 0.7115 Loss: 1.19705892 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 20.8323s
# Epoch: 0001 Accuracy: 0.7115 Loss: 1.19705892 time: 0.0000s
# Epoch: 1001 Accuracy: 0.7115 Loss: 1.19643569 time: 0.0000s
# Epoch: 2001 Accuracy: 0.7163 Loss: 1.19591439 time: 0.0040s
# Epoch: 3001 Accuracy: 0.7163 Loss: 1.19512796 time: 0.0000s
# Epoch: 4001 Accuracy: 0.7163 Loss: 1.19139385 time: 0.0040s
# Epoch: 5001 Accuracy: 0.7163 Loss: 1.19056261 time: 0.0000s
# Epoch: 6001 Accuracy: 0.7212 Loss: 1.18939424 time: 0.0000s
# Epoch: 7001 Accuracy: 0.7212 Loss: 1.18679214 time: 0.0040s
# Epoch: 8001 Accuracy: 0.7212 Loss: 1.18619895 time: 0.0040s
# Epoch: 9001 Accuracy: 0.7163 Loss: 1.18596625 time: 0.0000s
# Epoch: 10001 Accuracy: 0.7163 Loss: 1.18596625 time: 0.0040s
# Optimization Finished!
# Total time elapsed: 19.2390s
# Epoch: 0001 Accuracy: 0.7163 Loss: 1.18596625 time: 0.0000s
# Epoch: 1001 Accuracy: 0.7163 Loss: 1.18592060 time: 0.0040s
# Epoch: 2001 Accuracy: 0.7163 Loss: 1.18583035 time: 0.0000s
# Epoch: 3001 Accuracy: 0.7163 Loss: 1.18568039 time: 0.0040s
# Epoch: 4001 Accuracy: 0.7212 Loss: 1.18541741 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7212 Loss: 1.18514454 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7212 Loss: 1.18352270 time: 0.0030s
# Epoch: 7001 Accuracy: 0.7212 Loss: 1.18274760 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7212 Loss: 1.18274760 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7212 Loss: 1.18274760 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7212 Loss: 1.18274760 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 21.0410s
# Epoch: 0001 Accuracy: 0.7212 Loss: 1.18274760 time: 0.0030s
# Epoch: 1001 Accuracy: 0.7212 Loss: 1.18216753 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7212 Loss: 1.18108964 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7260 Loss: 1.17869449 time: 0.0010s
# Epoch: 4001 Accuracy: 0.7212 Loss: 1.17578983 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7212 Loss: 1.17578983 time: 0.0000s
# Epoch: 6001 Accuracy: 0.7212 Loss: 1.17578983 time: 0.0040s
# Epoch: 7001 Accuracy: 0.7212 Loss: 1.17578983 time: 0.0040s
# Epoch: 8001 Accuracy: 0.7212 Loss: 1.17578983 time: 0.0040s
# Epoch: 9001 Accuracy: 0.7212 Loss: 1.17578983 time: 0.0000s
# Epoch: 10001 Accuracy: 0.7212 Loss: 1.17578983 time: 0.0040s
# Optimization Finished!
# Total time elapsed: 20.9898s
# Epoch: 0001 Accuracy: 0.7212 Loss: 1.17578983 time: 0.0040s
# Epoch: 1001 Accuracy: 0.7308 Loss: 1.17526746 time: 0.0000s
# Epoch: 2001 Accuracy: 0.7308 Loss: 1.17460060 time: 0.0000s
# Epoch: 3001 Accuracy: 0.7260 Loss: 1.17382765 time: 0.0040s
# Epoch: 4001 Accuracy: 0.7308 Loss: 1.17195690 time: 0.0000s
# Epoch: 5001 Accuracy: 0.7308 Loss: 1.17166483 time: 0.0000s
# Epoch: 6001 Accuracy: 0.7308 Loss: 1.17166483 time: 0.0070s
# Epoch: 7001 Accuracy: 0.7308 Loss: 1.17166483 time: 0.0030s
# Epoch: 8001 Accuracy: 0.7308 Loss: 1.17166483 time: 0.0040s
# Epoch: 9001 Accuracy: 0.7308 Loss: 1.17166483 time: 0.0040s
# Epoch: 10001 Accuracy: 0.7308 Loss: 1.17166483 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 22.0618s
# Epoch: 0001 Accuracy: 0.7308 Loss: 1.17166483 time: 0.0000s
# Epoch: 1001 Accuracy: 0.7308 Loss: 1.17136312 time: 0.0040s
# Epoch: 2001 Accuracy: 0.7308 Loss: 1.17053115 time: 0.0040s
# Epoch: 3001 Accuracy: 0.7308 Loss: 1.17017853 time: 0.0040s
# Epoch: 4001 Accuracy: 0.7308 Loss: 1.17012477 time: 0.0000s
# Epoch: 5001 Accuracy: 0.7308 Loss: 1.17005265 time: 0.0070s
# Epoch: 6001 Accuracy: 0.7308 Loss: 1.16996253 time: 0.0000s
# Epoch: 7001 Accuracy: 0.7308 Loss: 1.16978538 time: 0.0000s
# Epoch: 8001 Accuracy: 0.7356 Loss: 1.16955698 time: 0.0000s
# Epoch: 9001 Accuracy: 0.7356 Loss: 1.16920042 time: 0.0040s
# Epoch: 10001 Accuracy: 0.7356 Loss: 1.16920042 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 21.6970s
# Epoch: 0001 Accuracy: 0.7356 Loss: 1.16920042 time: 0.0040s
# Epoch: 1001 Accuracy: 0.7356 Loss: 1.16919255 time: 0.0000s
# Epoch: 2001 Accuracy: 0.7356 Loss: 1.16918218 time: 0.0000s
# Epoch: 3001 Accuracy: 0.7356 Loss: 1.16917229 time: 0.0040s
# Epoch: 4001 Accuracy: 0.7356 Loss: 1.16916406 time: 0.0000s
# Epoch: 5001 Accuracy: 0.7356 Loss: 1.16915298 time: 0.0000s
# Epoch: 6001 Accuracy: 0.7356 Loss: 1.16913712 time: 0.0000s
# Epoch: 7001 Accuracy: 0.7356 Loss: 1.16911149 time: 0.0040s
# Epoch: 8001 Accuracy: 0.7356 Loss: 1.16905320 time: 0.0040s
# Epoch: 9001 Accuracy: 0.7404 Loss: 1.16426253 time: 0.0040s
# Epoch: 10001 Accuracy: 0.7404 Loss: 1.16426253 time: 0.0040s
# Optimization Finished!
# Total time elapsed: 18.2846s
# Epoch: 0001 Accuracy: 0.7404 Loss: 1.16426253 time: 0.0040s
# Epoch: 1001 Accuracy: 0.7404 Loss: 1.16398251 time: 0.0040s
# Epoch: 2001 Accuracy: 0.7404 Loss: 1.16398120 time: 0.0000s
# Epoch: 3001 Accuracy: 0.7404 Loss: 1.16397786 time: 0.0040s
# Epoch: 4001 Accuracy: 0.7404 Loss: 1.16397226 time: 0.0000s
# Epoch: 5001 Accuracy: 0.7404 Loss: 1.16396320 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7404 Loss: 1.16395056 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7404 Loss: 1.16392517 time: 0.0040s
# Epoch: 8001 Accuracy: 0.7404 Loss: 1.16383648 time: 0.0000s
# Epoch: 9001 Accuracy: 0.7404 Loss: 1.16356504 time: 0.0040s
# Epoch: 10001 Accuracy: 0.7404 Loss: 1.16349697 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 22.5272s
# Epoch: 0001 Accuracy: 0.7404 Loss: 1.16349697 time: 0.0040s
# Epoch: 1001 Accuracy: 0.7404 Loss: 1.16349685 time: 0.0000s
# Epoch: 2001 Accuracy: 0.7404 Loss: 1.16349673 time: 0.0000s
# Epoch: 3001 Accuracy: 0.7404 Loss: 1.16349673 time: 0.0000s
# Epoch: 4001 Accuracy: 0.7404 Loss: 1.16349673 time: 0.0040s
# Epoch: 5001 Accuracy: 0.7404 Loss: 1.16349661 time: 0.0000s
# Epoch: 6001 Accuracy: 0.7404 Loss: 1.16349649 time: 0.0040s
# Epoch: 7001 Accuracy: 0.7404 Loss: 1.16349638 time: 0.0000s
# Epoch: 8001 Accuracy: 0.7404 Loss: 1.16349626 time: 0.0040s
# Epoch: 9001 Accuracy: 0.7404 Loss: 1.16349614 time: 0.0000s
# Epoch: 10001 Accuracy: 0.7404 Loss: 1.16349566 time: 0.0040s
# Optimization Finished!
# Total time elapsed: 18.1908s
# Epoch: 0001 Accuracy: 0.7404 Loss: 1.16349566 time: 0.0000s
# Epoch: 1001 Accuracy: 0.7404 Loss: 1.16349554 time: 0.0040s
# Epoch: 2001 Accuracy: 0.7404 Loss: 1.16349554 time: 0.0040s
# Epoch: 3001 Accuracy: 0.7404 Loss: 1.16349554 time: 0.0040s
# Epoch: 4001 Accuracy: 0.7404 Loss: 1.16349554 time: 0.0040s
# Epoch: 5001 Accuracy: 0.7404 Loss: 1.16349554 time: 0.0040s
# Epoch: 6001 Accuracy: 0.7404 Loss: 1.16349542 time: 0.0040s
# Epoch: 7001 Accuracy: 0.7404 Loss: 1.16349542 time: 0.0030s
# Epoch: 8001 Accuracy: 0.7404 Loss: 1.16349351 time: 0.0030s
# Epoch: 9001 Accuracy: 0.7404 Loss: 1.16340709 time: 0.0040s
# Epoch: 10001 Accuracy: 0.7452 Loss: 1.16105652 time: 0.0040s
# Optimization Finished!
# Total time elapsed: 24.0034s
# Epoch: 0001 Accuracy: 0.7452 Loss: 1.16105652 time: 0.0000s
# Epoch: 1001 Accuracy: 0.7452 Loss: 1.16098619 time: 0.0040s
# Epoch: 2001 Accuracy: 0.7452 Loss: 1.16081083 time: 0.0040s
# Epoch: 3001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0040s
# Epoch: 4001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0000s
# Epoch: 5001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0040s
# Epoch: 7001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0000s
# Epoch: 8001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0040s
# Epoch: 9001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0000s
# Epoch: 10001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 20.9367s
# Epoch: 0001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0000s
# Epoch: 1001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0000s
# Epoch: 2001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0000s
# Epoch: 3001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0000s
# Epoch: 4001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0000s
# Epoch: 5001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0000s
# Epoch: 6001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0040s
# Epoch: 7001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0000s
# Epoch: 8001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0040s
# Epoch: 9001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0000s
# Epoch: 10001 Accuracy: 0.7452 Loss: 1.15964055 time: 0.0040s
# Optimization Finished!
# Total time elapsed: 19.5237s
