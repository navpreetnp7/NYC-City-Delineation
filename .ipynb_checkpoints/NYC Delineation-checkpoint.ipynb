# %%
import networkx as nx
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module
torch.set_printoptions(sci_mode=False)
import time

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('data/zips_merged.csv', delimiter=',')
data = data.rename(columns={'total': 'weight', 'w_zip':'origin', 'h_zip':'destination'})
data = data[data.destination.isin(data.origin.unique())]
data.head()
# Out:
#    origin  destination  weight  initialFeat  true_label
# 0   11436        10009       1          4.0           4
# 1   11436        10011       1          4.0           4
# 2   11436        10013       1          4.0           4
# 3   11436        10019       1          4.0           4
# 4   11436        10021       1          4.0           4

# %%
populationByAge = pd.read_csv('data/zicode_populationByAge.csv', delimiter=',')
populationByAge = populationByAge.iloc[:,0:2]
populationByAge.rename(columns={'ZIPCODE':'destination'}, inplace=True)

# %%
housePrice = pd.read_csv('data/zipcode_housePrice.csv', delimiter=',')
weights = [5000,12500,17500,22500,27500,32500,37500,45000,55000,65000,75000,85000
                    ,95000,112500,137500,162500,187500,225000,275000,350000,450000,625000,875000
                        ,1250000,1750000,2000000]
for i in range(len(weights)):
    housePrice.iloc[i,2:] = housePrice.iloc[i,2:]*weights[i]
housePrice.iloc[:,1] [housePrice.iloc[:,1] == 0] = 1

tmp = (housePrice.iloc[:,2:] != 0 ).sum(axis=1)
tmp[tmp == 0] = 1
housePrice = pd.concat([housePrice.iloc[:,0],housePrice.iloc[:,2:].sum(axis=1) / tmp ], axis = 1 )
housePrice.rename(columns={'ZIPCODE':'destination'}, inplace=True)

# %%
area = pd.read_csv('data/zips_area.csv', delimiter=',')
area = area.iloc[:,:2]
area.rename(columns={'ZIPCODE':'destination'}, inplace=True)

# %%
income = pd.read_csv('data/zipcode_income.csv', delimiter=',')
income = income.iloc[:,:2]
income[income.isna()] = 0
income.rename(columns={'ZIPCODE':'destination'}, inplace=True)

# %%
populationJobs = pd.read_csv('data/zipcode_population_Jobs.csv', delimiter=',')
populationJobs = populationJobs.iloc[:,:2]
populationJobs.rename(columns={'ZIPCODE':'destination'}, inplace=True)

# %%
data = data.merge(populationByAge)
data = data.merge(housePrice)
data = data.merge(area)
data = data.merge(income)
data = data.merge(populationJobs)

# %%
data
# Out:
#        origin  destination  weight  initialFeat  true_label  \
# 0       11436        10009       1          4.0           4
# 1       11213        10009      14          3.0           3
# 2       11212        10009      27          3.0           3
# 3       11225        10009      26          3.0           3
# 4       11218        10009      60          3.0           3
# ...       ...          ...     ...          ...         ...
# 36407   11211        11371       7          1.0           3
# 36408   11373        11371       3          4.0           4
# 36409   10168        11371       1          1.0           1
# 36410   10278        11371       1          1.0           1
# 36411   10036        11371       5          1.0           1
#
#        Estimate!!Total!!Total population          0          AREA  \
# 0                                  33620  1200000.0  1.590352e+07
# 1                                  33620  1200000.0  1.590352e+07
# 2                                  33620  1200000.0  1.590352e+07
# 3                                  33620  1200000.0  1.590352e+07
# 4                                  33620  1200000.0  1.590352e+07
# ...                                  ...        ...           ...
# 36407                                  0        0.0  3.055847e+07
# 36408                                  0        0.0  3.055847e+07
# 36409                                  0        0.0  3.055847e+07
# 36410                                  0        0.0  3.055847e+07
# 36411                                  0        0.0  3.055847e+07
#
#        median_familyIncome(USD)  totalJobs
# 0                   60994.34833       8929
# 1                   60994.34833       8929
# 2                   60994.34833       8929
# 3                   60994.34833       8929
# 4                   60994.34833       8929
# ...                         ...        ...
# 36407                   0.00000      10651
# 36408                   0.00000      10651
# 36409                   0.00000      10651
# 36410                   0.00000      10651
# 36411                   0.00000      10651
#
# [36412 rows x 10 columns]

# %%
cuda = torch.cuda.is_available()
weight_decay = 10e-4
epochs = 10001
seed = 165
hidden = 10
lr = 0.0001

# %%
np.random.seed(seed)
torch.manual_seed(seed)
if cuda:
    torch.cuda.manual_seed(seed)

# %%
def normalize(adj):

    adj = torch.FloatTensor(adj)
    adj_id = torch.FloatTensor(torch.eye(adj.shape[1]))
    adj_id = adj_id.reshape((1, adj.shape[1], adj.shape[1]))
    adj_id = adj_id.repeat(adj.shape[0], 1, 1)
    adj = adj + adj_id
    rowsum = torch.FloatTensor(adj.sum(2))
    degree_mat_inv_sqrt = torch.diag_embed(torch.float_power(rowsum,-0.5), dim1=-2, dim2=-1).float()
    adj_norm = torch.bmm(torch.transpose(torch.bmm(adj,degree_mat_inv_sqrt),1,2),degree_mat_inv_sqrt)

    return adj_norm


def doublerelu(x):
    return torch.clamp(x, 0, 1)

class GNN1Layer(Module):

    def __init__(self, batch_size, in_features, out_features, first):
        super(GNN1Layer, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.batch_size = batch_size

        weight1_eye = torch.FloatTensor(torch.eye(in_features, out_features))
        weight1_eye = weight1_eye.reshape((1, in_features, out_features))
        weight1_eye = weight1_eye.repeat(batch_size, 1, 1)
        self.weight1 = Parameter(weight1_eye)
        if not first:
            self.weight2 = Parameter(torch.zeros(batch_size, in_features, out_features))
        else:
            self.weight2 = Parameter(torch.empty(batch_size, in_features, out_features))
            nn.init.kaiming_normal_(self.weight2, mode='fan_out')

    def forward(self, input, adj):
        v1 = torch.bmm(input, self.weight1)
        v2 = torch.bmm(torch.bmm(adj, input), self.weight2)
        output = v1 + v2
        return output

# %%
class GNN1(nn.Module):

    def __init__(self, batch_size, nfeat, ndim, hidden, first):
        super(GNN1, self).__init__()

        self.gc1 = GNN1Layer(batch_size, nfeat, ndim, first)

    def forward(self, x, adj, random_indices):
        f = torch.clone(x)
        x = doublerelu(self.gc1(x, adj))
        x = x/x.sum(axis=2).unsqueeze(2) #normalize st sum = 1

        f[0][random_indices, :x.shape[2]] = x[0][random_indices, :]
        
        return f[:,:,:x.shape[2]]

# %%
def train(adj,features,labels,random_indices,first=False):
    
    adj_norm = normalize(adj)
    
    labels = labels - 1
    
    adj = torch.FloatTensor(adj)
    adj_norm = torch.FloatTensor(adj_norm)
    features = torch.FloatTensor(features)
    labels = torch.FloatTensor(labels)
    
    embedx, embedy = svdApprox(adj,dim=3)
    embedx = embedx.unsqueeze(0)
    embedy = embedy.unsqueeze(0)
    features = torch.cat((features,embedx,embedy),axis=2)
    
    model = GNN1(batch_size=adj.shape[0],
                nfeat=features.shape[-1],
                ndim=nb_label,
                hidden=hidden,
                first=first)
    if cuda:
        model.cuda()
        features = features.cuda()
        adj = adj.cuda()
        adj_norm = adj_norm.cuda()
        labels = labels.cuda()
    
    # Train model
    t_total = time.time()

    optimizer = optim.Adam(model.parameters(),
                           lr=lr, weight_decay=weight_decay)
    
    criterion = nn.CrossEntropyLoss()
    
    for epoch in range(epochs):

        t = time.time()
        model.train()
        optimizer.zero_grad()

        output = model(features, adj_norm, random_indices)
            
        accuracy = torch.sum(torch.argmax(output,axis=2)==labels.reshape(1,-1))/labels.shape[0]
        
        loss = criterion(output[0],labels.reshape(-1).long())

        loss.backward(retain_graph=True)

        optimizer.step()

        if epoch == 0:
            best_loss = loss
            best_output = output
            best_acc = accuracy
        else:
            if loss < best_loss:
                best_loss = loss
                best_output = output
                best_acc = accuracy

        if epoch % 1000 == 0:
            print('Epoch: {:04d}'.format(epoch + 1),
                  'Accuracy: {:.4f}'.format(best_acc.item()),
                  'Loss: {:.8f}'.format(best_loss.item()),
                  'time: {:.4f}s'.format(time.time() - t))
            
    print("Optimization Finished!")
    print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
    
    return best_loss,best_output

# %%
def svdApprox(adj, dim, relu=False):
    adj = torch.FloatTensor(adj[0])
    U, S, Vh = torch.linalg.svd(adj)
    mu = torch.matmul(torch.matmul(U[:, :dim], torch.diag(S[:dim])), Vh[:dim, :])

    embedx = torch.matmul(U[:, :dim], torch.diag(torch.pow(S[:dim], 0.5)))
    embedy = torch.transpose(torch.matmul(torch.diag(torch.pow(S[:dim], 0.5)), Vh[:dim, :]), 0, 1)

    return embedx, embedy

# %%
def load_data():

    G = nx.from_pandas_edgelist(data, 'origin', 'destination', 'weight',create_using=nx.DiGraph())
    adj_list = np.array([nx.adjacency_matrix(G).todense()], dtype=float)
    init_feat = np.array(data.groupby('origin')['initialFeat'].agg(['unique']))
    true_label = np.array(data.groupby('origin')['true_label'].agg(['unique']))
    init_feat = np.array(list(map(lambda x: x[0], init_feat))).reshape(-1, 1)
    true_label = np.array(list(map(lambda x: x[0][0], true_label))).reshape(-1, 1)
    return adj_list,init_feat,true_label

adj,feature,labels = load_data()

feature = feature - 1
nb_label = int(max(feature)) + 1
featuress = np.eye(nb_label)[np.array(feature,dtype=int).reshape(1,-1)]

# %%
mask_percentage = [1.]

for m in mask_percentage:
    
    features = np.copy(featuress)
    
    
    # Masking
    number_of_rows = features[0].shape[0]
    random_indices = np.random.choice(number_of_rows, size=int(m*number_of_rows), replace=False)
    
    # exclude low activity areas from masking
    zip_sum = data.groupby(by='origin', as_index=False).sum()
    low_act = zip_sum[zip_sum.weight < 3000].index
    
    random_indices = np.setdiff1d(random_indices, low_act)
    random_rows = features[0][random_indices, :]
    features[0][random_indices, :] = np.tile(np.array([[0.2]]),random_rows.shape)
    
    
    print("\nMasked {}% of nodes\n".format(int(m*100)))
    prev_loss, op = train(adj,features,labels, random_indices, True)
    #print(op)
    loss, op = train(adj,op.cpu().detach().numpy(),labels, random_indices)
    while loss < prev_loss :
        prev_loss = loss
        loss, op = train(adj,op.cpu().detach().numpy(),labels, random_indices)
# Out:
# Masked 100% of nodes
#
# Epoch: 0001 Accuracy: 0.2260 Loss: 1.64880872 time: 0.3890s
# Epoch: 1001 Accuracy: 0.3077 Loss: 1.63963807 time: 0.0020s
# Epoch: 2001 Accuracy: 0.3077 Loss: 1.63963807 time: 0.0010s
# Epoch: 3001 Accuracy: 0.3077 Loss: 1.63963807 time: 0.0020s
# Epoch: 4001 Accuracy: 0.3077 Loss: 1.63963807 time: 0.0010s
# Epoch: 5001 Accuracy: 0.3077 Loss: 1.63963807 time: 0.0020s
# Epoch: 6001 Accuracy: 0.3077 Loss: 1.63963807 time: 0.0020s
# Epoch: 7001 Accuracy: 0.3077 Loss: 1.63963807 time: 0.0020s
# Epoch: 8001 Accuracy: 0.3077 Loss: 1.63963807 time: 0.0020s
# Epoch: 9001 Accuracy: 0.3077 Loss: 1.63963807 time: 0.0020s
# Epoch: 10001 Accuracy: 0.3077 Loss: 1.63963807 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 18.3905s
# Epoch: 0001 Accuracy: 0.3077 Loss: 1.63963807 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6442 Loss: 1.25525355 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6442 Loss: 1.25525355 time: 0.0010s
# Epoch: 3001 Accuracy: 0.6442 Loss: 1.25525355 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6442 Loss: 1.25525355 time: 0.0020s
# Epoch: 5001 Accuracy: 0.6442 Loss: 1.25525355 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6442 Loss: 1.25525355 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6442 Loss: 1.25525355 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6442 Loss: 1.25525355 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6442 Loss: 1.25525355 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6442 Loss: 1.25525355 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 18.9920s
# Epoch: 0001 Accuracy: 0.6442 Loss: 1.25525355 time: 0.0030s
# Epoch: 1001 Accuracy: 0.6971 Loss: 1.22743511 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6971 Loss: 1.22743511 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6971 Loss: 1.22743511 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6971 Loss: 1.22743511 time: 0.0030s
# Epoch: 5001 Accuracy: 0.6971 Loss: 1.22743511 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6971 Loss: 1.22743511 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6971 Loss: 1.22743511 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6971 Loss: 1.22743511 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6971 Loss: 1.22743511 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6971 Loss: 1.22743511 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 19.3742s
# Epoch: 0001 Accuracy: 0.6971 Loss: 1.22743511 time: 0.0030s
# Epoch: 1001 Accuracy: 0.7212 Loss: 1.19296432 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7212 Loss: 1.19296432 time: 0.0022s
# Epoch: 3001 Accuracy: 0.7212 Loss: 1.19296432 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7212 Loss: 1.19296432 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7212 Loss: 1.19296432 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7212 Loss: 1.19296432 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7212 Loss: 1.19296432 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7212 Loss: 1.19296432 time: 0.0030s
# Epoch: 9001 Accuracy: 0.7212 Loss: 1.19296432 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7212 Loss: 1.19296432 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.8863s
# Epoch: 0001 Accuracy: 0.7212 Loss: 1.19296432 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7308 Loss: 1.18436277 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7308 Loss: 1.18436277 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7308 Loss: 1.18436277 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7308 Loss: 1.18436277 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7308 Loss: 1.18436277 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7308 Loss: 1.18436277 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7308 Loss: 1.18436277 time: 0.0010s
# Epoch: 8001 Accuracy: 0.7308 Loss: 1.18436277 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7308 Loss: 1.18436277 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7308 Loss: 1.18436277 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 18.9874s
# Epoch: 0001 Accuracy: 0.7308 Loss: 1.18436277 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7356 Loss: 1.16814315 time: 0.0019s
# Epoch: 2001 Accuracy: 0.7356 Loss: 1.16814315 time: 0.0017s
# Epoch: 3001 Accuracy: 0.7356 Loss: 1.16814315 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7356 Loss: 1.16814315 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7356 Loss: 1.16814315 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7356 Loss: 1.16814315 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7356 Loss: 1.16814315 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7356 Loss: 1.16814315 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7356 Loss: 1.16814315 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7356 Loss: 1.16814315 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 20.1467s
# Epoch: 0001 Accuracy: 0.7356 Loss: 1.16814315 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7404 Loss: 1.16471851 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7404 Loss: 1.16471851 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7404 Loss: 1.16471851 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7404 Loss: 1.16471851 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7404 Loss: 1.16471851 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7404 Loss: 1.16471851 time: 0.0019s
# Epoch: 7001 Accuracy: 0.7404 Loss: 1.16471851 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7404 Loss: 1.16471851 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7404 Loss: 1.16471851 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7404 Loss: 1.16471851 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.4557s
# Epoch: 0001 Accuracy: 0.7404 Loss: 1.16471851 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7452 Loss: 1.15689516 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7452 Loss: 1.15689516 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7452 Loss: 1.15689516 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7452 Loss: 1.15689516 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7452 Loss: 1.15689516 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7452 Loss: 1.15689516 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7452 Loss: 1.15689516 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7452 Loss: 1.15689516 time: 0.0030s
# Epoch: 9001 Accuracy: 0.7452 Loss: 1.15689516 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7452 Loss: 1.15689516 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 20.3005s
# Epoch: 0001 Accuracy: 0.7452 Loss: 1.15689516 time: 0.0030s
# Epoch: 1001 Accuracy: 0.7500 Loss: 1.14911997 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7500 Loss: 1.14911997 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7500 Loss: 1.14911997 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7500 Loss: 1.14911997 time: 0.0019s
# Epoch: 5001 Accuracy: 0.7500 Loss: 1.14911997 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7500 Loss: 1.14911997 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7500 Loss: 1.14911997 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7500 Loss: 1.14911997 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7500 Loss: 1.14911997 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7500 Loss: 1.14911997 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.8728s
# Epoch: 0001 Accuracy: 0.7500 Loss: 1.14911997 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7500 Loss: 1.14310658 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7500 Loss: 1.14310658 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7500 Loss: 1.14310658 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7500 Loss: 1.14310658 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7500 Loss: 1.14310658 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7500 Loss: 1.14310658 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7500 Loss: 1.14310658 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7500 Loss: 1.14310658 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7500 Loss: 1.14310658 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7500 Loss: 1.14310658 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.4081s
# Epoch: 0001 Accuracy: 0.7500 Loss: 1.14310658 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7644 Loss: 1.13740993 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7644 Loss: 1.13740993 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7644 Loss: 1.13740993 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7644 Loss: 1.13740993 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7644 Loss: 1.13740993 time: 0.0030s
# Epoch: 6001 Accuracy: 0.7644 Loss: 1.13740993 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7644 Loss: 1.13740993 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7644 Loss: 1.13740993 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7644 Loss: 1.13740993 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7644 Loss: 1.13740993 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.7470s
# Epoch: 0001 Accuracy: 0.7644 Loss: 1.13740993 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7644 Loss: 1.13354671 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7644 Loss: 1.13354671 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7644 Loss: 1.13354671 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7644 Loss: 1.13354671 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7644 Loss: 1.13354671 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7644 Loss: 1.13354671 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7644 Loss: 1.13354671 time: 0.0030s
# Epoch: 8001 Accuracy: 0.7644 Loss: 1.13354671 time: 0.0030s
# Epoch: 9001 Accuracy: 0.7644 Loss: 1.13354671 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7644 Loss: 1.13354671 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.7770s
# Epoch: 0001 Accuracy: 0.7644 Loss: 1.13354671 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7644 Loss: 1.12979722 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7644 Loss: 1.12979722 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7644 Loss: 1.12979722 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7644 Loss: 1.12979722 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7644 Loss: 1.12979722 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7644 Loss: 1.12979722 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7644 Loss: 1.12979722 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7644 Loss: 1.12979722 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7644 Loss: 1.12979722 time: 0.0030s
# Epoch: 10001 Accuracy: 0.7644 Loss: 1.12979722 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 20.2791s
# Epoch: 0001 Accuracy: 0.7644 Loss: 1.12979722 time: 0.0030s
# Epoch: 1001 Accuracy: 0.7740 Loss: 1.12623227 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7740 Loss: 1.12623227 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7740 Loss: 1.12623227 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7740 Loss: 1.12623227 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7740 Loss: 1.12623227 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7740 Loss: 1.12623227 time: 0.0017s
# Epoch: 7001 Accuracy: 0.7740 Loss: 1.12623227 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7740 Loss: 1.12623227 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7740 Loss: 1.12623227 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7740 Loss: 1.12623227 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.7311s
# Epoch: 0001 Accuracy: 0.7740 Loss: 1.12623227 time: 0.0030s
# Epoch: 1001 Accuracy: 0.7740 Loss: 1.12228286 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7740 Loss: 1.12228286 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7740 Loss: 1.12228286 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7740 Loss: 1.12228286 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7740 Loss: 1.12228286 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7740 Loss: 1.12228286 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7740 Loss: 1.12228286 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7740 Loss: 1.12228286 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7740 Loss: 1.12228286 time: 0.0030s
# Epoch: 10001 Accuracy: 0.7740 Loss: 1.12228286 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.8205s
# Epoch: 0001 Accuracy: 0.7740 Loss: 1.12228286 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7837 Loss: 1.11400270 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7933 Loss: 1.11037993 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7933 Loss: 1.11037993 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7933 Loss: 1.11037993 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7933 Loss: 1.11037993 time: 0.0019s
# Epoch: 6001 Accuracy: 0.7933 Loss: 1.11037993 time: 0.0030s
# Epoch: 7001 Accuracy: 0.7933 Loss: 1.11037993 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7933 Loss: 1.11037993 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7933 Loss: 1.11037993 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7933 Loss: 1.11037993 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.6790s
# Epoch: 0001 Accuracy: 0.7933 Loss: 1.11037993 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7933 Loss: 1.10558343 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7933 Loss: 1.10558343 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7933 Loss: 1.10558343 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7933 Loss: 1.10558343 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7933 Loss: 1.10558343 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7933 Loss: 1.10558343 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7933 Loss: 1.10558343 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7933 Loss: 1.10558343 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7933 Loss: 1.10558343 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7933 Loss: 1.10558343 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.5697s
# Epoch: 0001 Accuracy: 0.7933 Loss: 1.10558343 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7981 Loss: 1.09979463 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7981 Loss: 1.09979463 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7981 Loss: 1.09979463 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7981 Loss: 1.09979463 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7981 Loss: 1.09979463 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7981 Loss: 1.09979463 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7981 Loss: 1.09979463 time: 0.0030s
# Epoch: 8001 Accuracy: 0.7981 Loss: 1.09979463 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7981 Loss: 1.09979463 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7981 Loss: 1.09979463 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.7046s
# Epoch: 0001 Accuracy: 0.7981 Loss: 1.09979463 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8077 Loss: 1.09151828 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8077 Loss: 1.09151828 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8077 Loss: 1.09151828 time: 0.0030s
# Epoch: 4001 Accuracy: 0.8077 Loss: 1.09151828 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8077 Loss: 1.09151828 time: 0.0021s
# Epoch: 6001 Accuracy: 0.8077 Loss: 1.09151828 time: 0.0018s
# Epoch: 7001 Accuracy: 0.8077 Loss: 1.09151828 time: 0.0030s
# Epoch: 8001 Accuracy: 0.8077 Loss: 1.09151828 time: 0.0017s
# Epoch: 9001 Accuracy: 0.8077 Loss: 1.09151828 time: 0.0019s
# Epoch: 10001 Accuracy: 0.8077 Loss: 1.09151828 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.4538s
# Epoch: 0001 Accuracy: 0.8077 Loss: 1.09151828 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8173 Loss: 1.08826244 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8173 Loss: 1.08826244 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8173 Loss: 1.08826244 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8173 Loss: 1.08826244 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8173 Loss: 1.08826244 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8173 Loss: 1.08826244 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8173 Loss: 1.08826244 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8173 Loss: 1.08826244 time: 0.0030s
# Epoch: 9001 Accuracy: 0.8173 Loss: 1.08826244 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8173 Loss: 1.08826244 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.6408s
# Epoch: 0001 Accuracy: 0.8173 Loss: 1.08826244 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8173 Loss: 1.08531272 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8173 Loss: 1.08531272 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8173 Loss: 1.08531272 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8173 Loss: 1.08531272 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8173 Loss: 1.08531272 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8173 Loss: 1.08531272 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8173 Loss: 1.08531272 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8173 Loss: 1.08531272 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8173 Loss: 1.08531272 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8173 Loss: 1.08531272 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 18.9317s
# Epoch: 0001 Accuracy: 0.8173 Loss: 1.08531272 time: 0.0030s
# Epoch: 1001 Accuracy: 0.8221 Loss: 1.07994246 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8221 Loss: 1.07994246 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8221 Loss: 1.07994246 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8221 Loss: 1.07994246 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8221 Loss: 1.07994246 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8221 Loss: 1.07994246 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8221 Loss: 1.07994246 time: 0.0030s
# Epoch: 8001 Accuracy: 0.8221 Loss: 1.07994246 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8221 Loss: 1.07994246 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8221 Loss: 1.07994246 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.8168s
# Epoch: 0001 Accuracy: 0.8221 Loss: 1.07994246 time: 0.0030s
# Epoch: 1001 Accuracy: 0.8221 Loss: 1.07961726 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8221 Loss: 1.07936645 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8221 Loss: 1.07936645 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8221 Loss: 1.07936645 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8221 Loss: 1.07936645 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8221 Loss: 1.07936645 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8221 Loss: 1.07936645 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8221 Loss: 1.07936645 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8221 Loss: 1.07936645 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8221 Loss: 1.07936645 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 20.0289s
# Epoch: 0001 Accuracy: 0.8221 Loss: 1.07936645 time: 0.0030s
# Epoch: 1001 Accuracy: 0.8221 Loss: 1.07933295 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8221 Loss: 1.07927334 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8221 Loss: 1.07927334 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8221 Loss: 1.07927334 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8221 Loss: 1.07927334 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8221 Loss: 1.07927334 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8221 Loss: 1.07927334 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8221 Loss: 1.07927334 time: 0.0022s
# Epoch: 9001 Accuracy: 0.8221 Loss: 1.07927334 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8221 Loss: 1.07927334 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.2100s
# Epoch: 0001 Accuracy: 0.8221 Loss: 1.07927334 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8221 Loss: 1.07924294 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8221 Loss: 1.07919347 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8221 Loss: 1.07919347 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8221 Loss: 1.07919347 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8221 Loss: 1.07919347 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8221 Loss: 1.07919347 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8221 Loss: 1.07919347 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8221 Loss: 1.07919347 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8221 Loss: 1.07919347 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8221 Loss: 1.07919347 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.9864s
# Epoch: 0001 Accuracy: 0.8221 Loss: 1.07919347 time: 0.0030s
# Epoch: 1001 Accuracy: 0.8221 Loss: 1.07916820 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8221 Loss: 1.07910776 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8221 Loss: 1.07910776 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8221 Loss: 1.07910776 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8221 Loss: 1.07910776 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8221 Loss: 1.07910776 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8221 Loss: 1.07910776 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8221 Loss: 1.07910776 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8221 Loss: 1.07910776 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8221 Loss: 1.07910776 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 18.8872s
# Epoch: 0001 Accuracy: 0.8221 Loss: 1.07910776 time: 0.0030s
# Epoch: 1001 Accuracy: 0.8221 Loss: 1.07908034 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8221 Loss: 1.07902920 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8221 Loss: 1.07902920 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8221 Loss: 1.07902920 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8221 Loss: 1.07902920 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8221 Loss: 1.07902920 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8221 Loss: 1.07902920 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8221 Loss: 1.07902920 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8221 Loss: 1.07902920 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8221 Loss: 1.07902920 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.8383s
# Epoch: 0001 Accuracy: 0.8221 Loss: 1.07902920 time: 0.0030s
# Epoch: 1001 Accuracy: 0.8221 Loss: 1.07900488 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8221 Loss: 1.07895076 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8221 Loss: 1.07895076 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8221 Loss: 1.07895076 time: 0.0030s
# Epoch: 5001 Accuracy: 0.8221 Loss: 1.07895076 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8221 Loss: 1.07895076 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8221 Loss: 1.07895076 time: 0.0030s
# Epoch: 8001 Accuracy: 0.8221 Loss: 1.07895076 time: 0.0030s
# Epoch: 9001 Accuracy: 0.8221 Loss: 1.07895076 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8221 Loss: 1.07895076 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 20.8095s
# Epoch: 0001 Accuracy: 0.8221 Loss: 1.07895076 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8221 Loss: 1.07892501 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8221 Loss: 1.07887256 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8221 Loss: 1.07883346 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8221 Loss: 1.07883346 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8221 Loss: 1.07883346 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8221 Loss: 1.07883346 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8221 Loss: 1.07883346 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8221 Loss: 1.07883346 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8221 Loss: 1.07883346 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8221 Loss: 1.07883346 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.3387s
# Epoch: 0001 Accuracy: 0.8221 Loss: 1.07883346 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8221 Loss: 1.07880890 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8221 Loss: 1.07875049 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8221 Loss: 1.07875049 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8221 Loss: 1.07875049 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8221 Loss: 1.07875049 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8221 Loss: 1.07875049 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8221 Loss: 1.07875049 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8221 Loss: 1.07875049 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8221 Loss: 1.07875049 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8221 Loss: 1.07875049 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.9395s
# Epoch: 0001 Accuracy: 0.8221 Loss: 1.07875049 time: 0.0030s
# Epoch: 1001 Accuracy: 0.8221 Loss: 1.07872665 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8221 Loss: 1.07865834 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8221 Loss: 1.07865834 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8221 Loss: 1.07865834 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8221 Loss: 1.07865834 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8221 Loss: 1.07865834 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8221 Loss: 1.07865834 time: 0.0030s
# Epoch: 8001 Accuracy: 0.8221 Loss: 1.07865834 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8221 Loss: 1.07865834 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8221 Loss: 1.07865834 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.4922s
# Epoch: 0001 Accuracy: 0.8221 Loss: 1.07865834 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8221 Loss: 1.07862854 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8221 Loss: 1.07851112 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8269 Loss: 1.07523966 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8269 Loss: 1.07523966 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8269 Loss: 1.07523966 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8269 Loss: 1.07523966 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8269 Loss: 1.07523966 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8269 Loss: 1.07523966 time: 0.0010s
# Epoch: 9001 Accuracy: 0.8269 Loss: 1.07523966 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8269 Loss: 1.07523966 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.6002s
# Epoch: 0001 Accuracy: 0.8269 Loss: 1.07523966 time: 0.0030s
# Epoch: 1001 Accuracy: 0.8269 Loss: 1.07289433 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8269 Loss: 1.07289433 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8269 Loss: 1.07289433 time: 0.0030s
# Epoch: 4001 Accuracy: 0.8269 Loss: 1.07289433 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8269 Loss: 1.07289433 time: 0.0030s
# Epoch: 6001 Accuracy: 0.8269 Loss: 1.07289433 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8269 Loss: 1.07289433 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8269 Loss: 1.07289433 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8269 Loss: 1.07289433 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8269 Loss: 1.07289433 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.5376s
# Epoch: 0001 Accuracy: 0.8269 Loss: 1.07289433 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8269 Loss: 1.07141399 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8269 Loss: 1.07141399 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8269 Loss: 1.07141399 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8269 Loss: 1.07141399 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8269 Loss: 1.07141399 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8269 Loss: 1.07141399 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8269 Loss: 1.07141399 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8269 Loss: 1.07141399 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8269 Loss: 1.07141399 time: 0.0010s
# Epoch: 10001 Accuracy: 0.8269 Loss: 1.07141399 time: 0.0017s
# Optimization Finished!
# Total time elapsed: 19.4533s
# Epoch: 0001 Accuracy: 0.8269 Loss: 1.07141399 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8317 Loss: 1.06698251 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8317 Loss: 1.06698251 time: 0.0019s
# Epoch: 3001 Accuracy: 0.8317 Loss: 1.06698251 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8317 Loss: 1.06698251 time: 0.0022s
# Epoch: 5001 Accuracy: 0.8317 Loss: 1.06698251 time: 0.0030s
# Epoch: 6001 Accuracy: 0.8317 Loss: 1.06698251 time: 0.0030s
# Epoch: 7001 Accuracy: 0.8317 Loss: 1.06698251 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8317 Loss: 1.06698251 time: 0.0030s
# Epoch: 9001 Accuracy: 0.8317 Loss: 1.06698251 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8317 Loss: 1.06698251 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 20.6601s
# Epoch: 0001 Accuracy: 0.8317 Loss: 1.06698251 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8365 Loss: 1.06434989 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8365 Loss: 1.06434989 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8365 Loss: 1.06434989 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8365 Loss: 1.06434989 time: 0.0030s
# Epoch: 5001 Accuracy: 0.8365 Loss: 1.06434989 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8365 Loss: 1.06434989 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8365 Loss: 1.06434989 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8365 Loss: 1.06434989 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8365 Loss: 1.06434989 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8365 Loss: 1.06434989 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.4982s
# Epoch: 0001 Accuracy: 0.8365 Loss: 1.06434989 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8365 Loss: 1.06344593 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8365 Loss: 1.06344593 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8365 Loss: 1.06344593 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8365 Loss: 1.06344593 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8365 Loss: 1.06344593 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8365 Loss: 1.06344593 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8365 Loss: 1.06344593 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8365 Loss: 1.06344593 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8365 Loss: 1.06344593 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8365 Loss: 1.06344593 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.9389s
# Epoch: 0001 Accuracy: 0.8365 Loss: 1.06344593 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8365 Loss: 1.06254852 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8365 Loss: 1.06254852 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8365 Loss: 1.06254852 time: 0.0017s
# Epoch: 4001 Accuracy: 0.8365 Loss: 1.06254852 time: 0.0017s
# Epoch: 5001 Accuracy: 0.8365 Loss: 1.06254852 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8365 Loss: 1.06254852 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8365 Loss: 1.06254852 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8365 Loss: 1.06254852 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8365 Loss: 1.06254852 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8365 Loss: 1.06254852 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.6068s
# Epoch: 0001 Accuracy: 0.8365 Loss: 1.06254852 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8413 Loss: 1.06108546 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8413 Loss: 1.06083560 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8413 Loss: 1.06083560 time: 0.0030s
# Epoch: 4001 Accuracy: 0.8413 Loss: 1.06083560 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8413 Loss: 1.06083560 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8413 Loss: 1.06083560 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8413 Loss: 1.06083560 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8413 Loss: 1.06083560 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8413 Loss: 1.06083560 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8413 Loss: 1.06083560 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.5741s
# Epoch: 0001 Accuracy: 0.8413 Loss: 1.06083560 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8413 Loss: 1.05886221 time: 0.0030s
# Epoch: 2001 Accuracy: 0.8413 Loss: 1.05839121 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8413 Loss: 1.05823302 time: 0.0019s
# Epoch: 4001 Accuracy: 0.8413 Loss: 1.05823302 time: 0.0019s
# Epoch: 5001 Accuracy: 0.8413 Loss: 1.05823302 time: 0.0019s
# Epoch: 6001 Accuracy: 0.8413 Loss: 1.05823302 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8413 Loss: 1.05823302 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8413 Loss: 1.05823302 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8413 Loss: 1.05823302 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8413 Loss: 1.05823302 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.9162s
# Epoch: 0001 Accuracy: 0.8413 Loss: 1.05823302 time: 0.0030s
# Epoch: 1001 Accuracy: 0.8413 Loss: 1.05734777 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8413 Loss: 1.05734777 time: 0.0030s
# Epoch: 3001 Accuracy: 0.8413 Loss: 1.05734777 time: 0.0030s
# Epoch: 4001 Accuracy: 0.8413 Loss: 1.05734777 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8413 Loss: 1.05734777 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8413 Loss: 1.05734777 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8413 Loss: 1.05734777 time: 0.0030s
# Epoch: 8001 Accuracy: 0.8413 Loss: 1.05734777 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8413 Loss: 1.05734777 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8413 Loss: 1.05734777 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.9996s
# Epoch: 0001 Accuracy: 0.8413 Loss: 1.05734777 time: 0.0030s
# Epoch: 1001 Accuracy: 0.8462 Loss: 1.05584002 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8462 Loss: 1.05584002 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8462 Loss: 1.05584002 time: 0.0030s
# Epoch: 4001 Accuracy: 0.8462 Loss: 1.05584002 time: 0.0030s
# Epoch: 5001 Accuracy: 0.8462 Loss: 1.05584002 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8462 Loss: 1.05584002 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8462 Loss: 1.05584002 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8462 Loss: 1.05584002 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8462 Loss: 1.05584002 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8462 Loss: 1.05584002 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.7154s
# Epoch: 0001 Accuracy: 0.8462 Loss: 1.05584002 time: 0.0030s
# Epoch: 1001 Accuracy: 0.8510 Loss: 1.05406833 time: 0.0030s
# Epoch: 2001 Accuracy: 0.8510 Loss: 1.05377364 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8510 Loss: 1.05348480 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8510 Loss: 1.05334735 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8510 Loss: 1.05334735 time: 0.0022s
# Epoch: 6001 Accuracy: 0.8510 Loss: 1.05334735 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8510 Loss: 1.05334735 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8510 Loss: 1.05334735 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8510 Loss: 1.05334735 time: 0.0030s
# Epoch: 10001 Accuracy: 0.8510 Loss: 1.05334735 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.5727s
# Epoch: 0001 Accuracy: 0.8510 Loss: 1.05334735 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8510 Loss: 1.05319893 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8510 Loss: 1.05285716 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8510 Loss: 1.05236578 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8510 Loss: 1.05220592 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8510 Loss: 1.05220592 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8510 Loss: 1.05220592 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8510 Loss: 1.05220592 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8510 Loss: 1.05220592 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8510 Loss: 1.05220592 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8510 Loss: 1.05220592 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.5740s
# Epoch: 0001 Accuracy: 0.8510 Loss: 1.05220592 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8510 Loss: 1.05202568 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8510 Loss: 1.05173838 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8510 Loss: 1.05171001 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8510 Loss: 1.05164766 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8510 Loss: 1.05162311 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8510 Loss: 1.05159974 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8510 Loss: 1.05159974 time: 0.0019s
# Epoch: 8001 Accuracy: 0.8510 Loss: 1.05159974 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8510 Loss: 1.05159974 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8510 Loss: 1.05159974 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.5877s
# Epoch: 0001 Accuracy: 0.8510 Loss: 1.05159974 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8510 Loss: 1.05159962 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8510 Loss: 1.05159640 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8510 Loss: 1.05159271 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8510 Loss: 1.05158663 time: 0.0030s
# Epoch: 5001 Accuracy: 0.8510 Loss: 1.05157709 time: 0.0030s
# Epoch: 6001 Accuracy: 0.8510 Loss: 1.05156350 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8510 Loss: 1.05156171 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8510 Loss: 1.05156171 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8510 Loss: 1.05156171 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8510 Loss: 1.05156171 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 20.0800s
# Epoch: 0001 Accuracy: 0.8510 Loss: 1.05156171 time: 0.0030s
# Epoch: 1001 Accuracy: 0.8510 Loss: 1.05156171 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8510 Loss: 1.05156028 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8510 Loss: 1.05155742 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8510 Loss: 1.05155218 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8510 Loss: 1.05154622 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8510 Loss: 1.05153298 time: 0.0030s
# Epoch: 7001 Accuracy: 0.8510 Loss: 1.05153298 time: 0.0030s
# Epoch: 8001 Accuracy: 0.8510 Loss: 1.05153298 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8510 Loss: 1.05153298 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8510 Loss: 1.05153298 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.8699s
# Epoch: 0001 Accuracy: 0.8510 Loss: 1.05153298 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8510 Loss: 1.05153298 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8510 Loss: 1.05153191 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8510 Loss: 1.05152917 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8510 Loss: 1.05152750 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8510 Loss: 1.05150032 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8510 Loss: 1.05150032 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8510 Loss: 1.05150032 time: 0.0021s
# Epoch: 8001 Accuracy: 0.8510 Loss: 1.05150032 time: 0.0022s
# Epoch: 9001 Accuracy: 0.8510 Loss: 1.05150032 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8510 Loss: 1.05150032 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.4425s
# Epoch: 0001 Accuracy: 0.8510 Loss: 1.05150032 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8510 Loss: 1.05149889 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8510 Loss: 1.05149329 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8510 Loss: 1.05148721 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8510 Loss: 1.05148077 time: 0.0030s
# Epoch: 5001 Accuracy: 0.8510 Loss: 1.05147302 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8510 Loss: 1.05146253 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8510 Loss: 1.05145419 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8510 Loss: 1.05145419 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8510 Loss: 1.05145419 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8510 Loss: 1.05145419 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.4099s
# Epoch: 0001 Accuracy: 0.8510 Loss: 1.05145419 time: 0.0030s
# Epoch: 1001 Accuracy: 0.8510 Loss: 1.05145419 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8510 Loss: 1.05145383 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8510 Loss: 1.05145252 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8510 Loss: 1.05145001 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8510 Loss: 1.05144525 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8510 Loss: 1.05143642 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8510 Loss: 1.05142093 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8510 Loss: 1.05139208 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8510 Loss: 1.05138683 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8510 Loss: 1.05138683 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.0527s
# Epoch: 0001 Accuracy: 0.8510 Loss: 1.05138683 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8510 Loss: 1.05138671 time: 0.0030s
# Epoch: 2001 Accuracy: 0.8510 Loss: 1.05138612 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8510 Loss: 1.05138505 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8510 Loss: 1.05138290 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8510 Loss: 1.05137849 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8510 Loss: 1.05137169 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8510 Loss: 1.05136466 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8510 Loss: 1.05135274 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8510 Loss: 1.05135274 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8510 Loss: 1.05135274 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 20.2112s
# Epoch: 0001 Accuracy: 0.8510 Loss: 1.05135274 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8510 Loss: 1.05135274 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8510 Loss: 1.05135238 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8510 Loss: 1.05135202 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8510 Loss: 1.05135012 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8510 Loss: 1.05134702 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8510 Loss: 1.05134284 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8510 Loss: 1.05133653 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8510 Loss: 1.05133152 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8510 Loss: 1.05132473 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8510 Loss: 1.05132473 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.5891s
# Epoch: 0001 Accuracy: 0.8510 Loss: 1.05132473 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8510 Loss: 1.05132473 time: 0.0030s
# Epoch: 2001 Accuracy: 0.8510 Loss: 1.05132473 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8510 Loss: 1.05132473 time: 0.0030s
# Epoch: 4001 Accuracy: 0.8510 Loss: 1.05132413 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8510 Loss: 1.05132365 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8510 Loss: 1.05132246 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8510 Loss: 1.05132127 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8510 Loss: 1.05132091 time: 0.0022s
# Epoch: 9001 Accuracy: 0.8510 Loss: 1.05132067 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8510 Loss: 1.05132067 time: 0.0017s
# Optimization Finished!
# Total time elapsed: 19.4933s
# Epoch: 0001 Accuracy: 0.8510 Loss: 1.05132067 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8510 Loss: 1.05132067 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8510 Loss: 1.05132067 time: 0.0022s
# Epoch: 3001 Accuracy: 0.8510 Loss: 1.05132055 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8510 Loss: 1.05132055 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8510 Loss: 1.05132055 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8510 Loss: 1.05132031 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8510 Loss: 1.05132020 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8510 Loss: 1.05132020 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8510 Loss: 1.05132020 time: 0.0030s
# Epoch: 10001 Accuracy: 0.8510 Loss: 1.05132020 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.7833s
# Epoch: 0001 Accuracy: 0.8510 Loss: 1.05132020 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8510 Loss: 1.05132020 time: 0.0020s
# Epoch: 2001 Accuracy: 0.8510 Loss: 1.05132020 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8510 Loss: 1.05132020 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8510 Loss: 1.05132020 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8510 Loss: 1.05132020 time: 0.0010s
# Epoch: 6001 Accuracy: 0.8510 Loss: 1.05132020 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8510 Loss: 1.05132008 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8510 Loss: 1.05131996 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8510 Loss: 1.05131996 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8510 Loss: 1.05131996 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.0112s
# Epoch: 0001 Accuracy: 0.8510 Loss: 1.05131996 time: 0.0020s
# Epoch: 1001 Accuracy: 0.8510 Loss: 1.05131996 time: 0.0030s
# Epoch: 2001 Accuracy: 0.8510 Loss: 1.05131996 time: 0.0020s
# Epoch: 3001 Accuracy: 0.8510 Loss: 1.05131996 time: 0.0020s
# Epoch: 4001 Accuracy: 0.8510 Loss: 1.05131996 time: 0.0020s
# Epoch: 5001 Accuracy: 0.8510 Loss: 1.05131996 time: 0.0020s
# Epoch: 6001 Accuracy: 0.8510 Loss: 1.05131996 time: 0.0020s
# Epoch: 7001 Accuracy: 0.8510 Loss: 1.05131996 time: 0.0020s
# Epoch: 8001 Accuracy: 0.8510 Loss: 1.05131996 time: 0.0020s
# Epoch: 9001 Accuracy: 0.8510 Loss: 1.05131996 time: 0.0020s
# Epoch: 10001 Accuracy: 0.8510 Loss: 1.05131996 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 20.1634s
