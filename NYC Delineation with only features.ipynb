# %%
import networkx as nx
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module
torch.set_printoptions(sci_mode=False)
import time

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('data/zips_merged.csv', delimiter=',')
data = data.rename(columns={'total': 'weight', 'w_zip':'origin', 'h_zip':'destination'})
data = data[data.destination.isin(data.origin.unique())]
data.head()
# Out:
#    origin  destination  weight  initialFeat  true_label
# 0   11436        10009       1          4.0           4
# 1   11436        10011       1          4.0           4
# 2   11436        10013       1          4.0           4
# 3   11436        10019       1          4.0           4
# 4   11436        10021       1          4.0           4

# %%
populationByAge = pd.read_csv('data/zicode_populationByAge.csv', delimiter=',')
populationByAge = populationByAge.iloc[:,0:2]
populationByAge.rename(columns={'ZIPCODE':'destination'}, inplace=True)

# %%
housePrice = pd.read_csv('data/zipcode_housePrice.csv', delimiter=',')
weights = [5000,12500,17500,22500,27500,32500,37500,45000,55000,65000,75000,85000
                    ,95000,112500,137500,162500,187500,225000,275000,350000,450000,625000,875000
                        ,1250000,1750000,2000000]
for i in range(len(weights)):
    housePrice.iloc[i,2:] = housePrice.iloc[i,2:]*weights[i]
housePrice.iloc[:,1] [housePrice.iloc[:,1] == 0] = 1

tmp = (housePrice.iloc[:,2:] != 0 ).sum(axis=1)
tmp[tmp == 0] = 1
housePrice = pd.concat([housePrice.iloc[:,0],housePrice.iloc[:,2:].sum(axis=1) / tmp ], axis = 1 )
housePrice.rename(columns={'ZIPCODE':'destination'}, inplace=True)

# %%
area = pd.read_csv('data/zips_area.csv', delimiter=',')
area = area.iloc[:,:2]
area.rename(columns={'ZIPCODE':'destination'}, inplace=True)

# %%
income = pd.read_csv('data/zipcode_income.csv', delimiter=',')
income = income.iloc[:,:2]
income[income.isna()] = 0
income.rename(columns={'ZIPCODE':'destination'}, inplace=True)

# %%
populationJobs = pd.read_csv('data/zipcode_population_Jobs.csv', delimiter=',')
populationJobs = populationJobs.iloc[:,:2]
populationJobs.rename(columns={'ZIPCODE':'destination'}, inplace=True)

# %%
data = data.merge(populationByAge)
data = data.merge(housePrice)
data = data.merge(area)
data = data.merge(income)
data = data.merge(populationJobs)

# %%
data.iloc[:,5:]=(data.iloc[:,5:]-data.iloc[:,5:].min())/(data.iloc[:,5:].max()-data.iloc[:,5:].min())

# %%
data
# Out:
#        origin  destination  weight  initialFeat  true_label  \
# 0       11436        10009       1          4.0           4
# 1       11213        10009      14          3.0           3
# 2       11212        10009      27          3.0           3
# 3       11225        10009      26          3.0           3
# 4       11218        10009      60          3.0           3
# ...       ...          ...     ...          ...         ...
# 36407   11211        11371       7          1.0           3
# 36408   11373        11371       3          4.0           4
# 36409   10168        11371       1          1.0           1
# 36410   10278        11371       1          1.0           1
# 36411   10036        11371       5          1.0           1
#
#        Estimate!!Total!!Total population         0      AREA  \
# 0                               0.300165  0.005332  0.032183
# 1                               0.300165  0.005332  0.032183
# 2                               0.300165  0.005332  0.032183
# 3                               0.300165  0.005332  0.032183
# 4                               0.300165  0.005332  0.032183
# ...                                  ...       ...       ...
# 36407                           0.000000  0.000000  0.063146
# 36408                           0.000000  0.000000  0.063146
# 36409                           0.000000  0.000000  0.063146
# 36410                           0.000000  0.000000  0.063146
# 36411                           0.000000  0.000000  0.063146
#
#        median_familyIncome(USD)  totalJobs
# 0                      0.243977   0.042630
# 1                      0.243977   0.042630
# 2                      0.243977   0.042630
# 3                      0.243977   0.042630
# 4                      0.243977   0.042630
# ...                         ...        ...
# 36407                  0.000000   0.050874
# 36408                  0.000000   0.050874
# 36409                  0.000000   0.050874
# 36410                  0.000000   0.050874
# 36411                  0.000000   0.050874
#
# [36412 rows x 10 columns]

# %%
cuda = torch.cuda.is_available()
weight_decay = 10e-4
epochs = 10001
seed = 165
hidden = 10
lr = 0.0001

# %%
np.random.seed(seed)
torch.manual_seed(seed)
if cuda:
    torch.cuda.manual_seed(seed)

# %%
def normalize(adj):

    adj = torch.FloatTensor(adj)
    adj_id = torch.FloatTensor(torch.eye(adj.shape[1]))
    adj_id = adj_id.reshape((1, adj.shape[1], adj.shape[1]))
    adj_id = adj_id.repeat(adj.shape[0], 1, 1)
    adj = adj + adj_id
    rowsum = torch.FloatTensor(adj.sum(2))
    degree_mat_inv_sqrt = torch.diag_embed(torch.float_power(rowsum,-0.5), dim1=-2, dim2=-1).float()
    adj_norm = torch.bmm(torch.transpose(torch.bmm(adj,degree_mat_inv_sqrt),1,2),degree_mat_inv_sqrt)

    return adj_norm


def doublerelu(x):
    return torch.clamp(x, 0, 1)

class GNN1Layer(Module):

    def __init__(self, batch_size, in_features, out_features, first):
        super(GNN1Layer, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.batch_size = batch_size

        weight1_eye = torch.FloatTensor(torch.eye(in_features, out_features))
        weight1_eye = weight1_eye.reshape((1, in_features, out_features))
        weight1_eye = weight1_eye.repeat(batch_size, 1, 1)
        self.weight1 = Parameter(weight1_eye)
        if not first:
            self.weight2 = Parameter(torch.zeros(batch_size, in_features, out_features))
        else:
            self.weight2 = Parameter(torch.empty(batch_size, in_features, out_features))
            nn.init.kaiming_normal_(self.weight2, mode='fan_out')

    def forward(self, input, adj):
        v1 = torch.bmm(input, self.weight1)
        v2 = torch.bmm(torch.bmm(adj, input), self.weight2)
        output = v1 + v2
        return output

# %%
class GNN1(nn.Module):

    def __init__(self, batch_size, nfeat, ndim, hidden, first):
        super(GNN1, self).__init__()

        self.gc1 = GNN1Layer(batch_size, nfeat, ndim, first)

    def forward(self, x, adj, random_indices):
        f = torch.clone(x)
        x = doublerelu(self.gc1(x, adj))
        x = x/x.sum(axis=2).unsqueeze(2) #normalize st sum = 1

        f[0][random_indices, :x.shape[2]] = x[0][random_indices, :]
        
        return f[:,:,:x.shape[2]]

# %%
def train(adj,features,labels,random_indices,first=False):
    
    adj_norm = normalize(adj)
    
    labels = labels - 1
    
    adj = torch.FloatTensor(adj)
    adj_norm = torch.FloatTensor(adj_norm)
    features = torch.FloatTensor(features)
    labels = torch.FloatTensor(labels)
    
    model = GNN1(batch_size=adj.shape[0],
                nfeat=features.shape[-1],
                ndim=nb_label,
                hidden=hidden,
                first=first)
    if cuda:
        model.cuda()
        features = features.cuda()
        adj = adj.cuda()
        adj_norm = adj_norm.cuda()
        labels = labels.cuda()
    
    # Train model
    t_total = time.time()

    optimizer = optim.Adam(model.parameters(),
                           lr=lr, weight_decay=weight_decay)
    
    criterion = nn.CrossEntropyLoss()
    
    for epoch in range(epochs):

        t = time.time()
        model.train()
        optimizer.zero_grad()

        output = model(features, adj_norm, random_indices)
            
        accuracy = torch.sum(torch.argmax(output,axis=2)==labels.reshape(1,-1))/labels.shape[0]
        
        loss = criterion(output[0],labels.reshape(-1).long())

        loss.backward(retain_graph=True)

        optimizer.step()

        if epoch == 0:
            best_loss = loss
            best_output = output
            best_acc = accuracy
        else:
            if loss < best_loss:
                best_loss = loss
                best_output = output
                best_acc = accuracy

        if epoch % 1000 == 0:
            print('Epoch: {:04d}'.format(epoch + 1),
                  'Accuracy: {:.4f}'.format(best_acc.item()),
                  'Loss: {:.8f}'.format(best_loss.item()),
                  'time: {:.4f}s'.format(time.time() - t))
            
    print("Optimization Finished!")
    print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
    
    return best_loss,best_output

# %%
def svdApprox(adj, dim, relu=False):
    adj = torch.FloatTensor(adj[0])
    U, S, Vh = torch.linalg.svd(adj)
    mu = torch.matmul(torch.matmul(U[:, :dim], torch.diag(S[:dim])), Vh[:dim, :])

    embedx = torch.matmul(U[:, :dim], torch.diag(torch.pow(S[:dim], 0.5)))
    embedy = torch.transpose(torch.matmul(torch.diag(torch.pow(S[:dim], 0.5)), Vh[:dim, :]), 0, 1)

    return embedx, embedy

# %%
def load_data():

    G = nx.from_pandas_edgelist(data, 'origin', 'destination', 'weight',create_using=nx.DiGraph())
    adj_list = np.array([nx.adjacency_matrix(G).todense()], dtype=float)
    #init_feat = np.array(data.groupby('origin')['initialFeat'].agg(['unique']))
    
    init_feat1 = np.array(data.groupby('origin')['Estimate!!Total!!Total population'].agg(['unique']))
    init_feat1 = np.array(list(map(lambda x: x[0][0], init_feat1))).reshape(-1, 1)
    init_feat2 = np.array(data.groupby('origin')[0].agg(['unique']))
    init_feat2 = np.array(list(map(lambda x: x[0][0], init_feat2))).reshape(-1, 1)
    init_feat3 = np.array(data.groupby('origin')['AREA'].agg(['unique']))
    init_feat3 = np.array(list(map(lambda x: x[0][0], init_feat3))).reshape(-1, 1)
    init_feat4 = np.array(data.groupby('origin')['median_familyIncome(USD)'].agg(['unique']))
    init_feat4 = np.array(list(map(lambda x: x[0][0], init_feat4))).reshape(-1, 1)
    init_feat5 = np.array(data.groupby('origin')['totalJobs'].agg(['unique']))
    init_feat5 = np.array(list(map(lambda x: x[0][0], init_feat5))).reshape(-1, 1)
    
    init_feat = np.concatenate([init_feat1,init_feat2,init_feat3,init_feat4,init_feat5],axis=1)
    
    true_label = np.array(data.groupby('origin')['true_label'].agg(['unique']))
    
    true_label = np.array(list(map(lambda x: x[0][0], true_label))).reshape(-1, 1)
    return adj_list,init_feat,true_label

adj,feature,labels = load_data()

#feature = feature - 1
#nb_label = int(max(feature)) + 1
#featuress = np.eye(nb_label)[np.array(feature,dtype=int).reshape(1,-1)]

# %%
init_feat = np.array(data.groupby('origin')['initialFeat'].agg(['unique']))
init_feat = np.array(list(map(lamba x: x[0][0], init_feat))).reshape(-1, 1)
init_feat = init_feat - 1
nb_label = int(max(init_feat)) + 1

# %%
mask_percentage = [1.]

for m in mask_percentage:
    
    features = np.expand_dims(feature, axis=0)
    #print(features.shape)
    
    # Masking
    number_of_rows = features[0].shape[0]
    random_indices = np.random.choice(number_of_rows, size=int(m*number_of_rows), replace=False)
    
    # exclude low activity areas from masking
    zip_sum = data.groupby(by='origin', as_index=False).sum()
    low_act = zip_sum[zip_sum.weight < 3000].index
    
    random_indices = np.setdiff1d(random_indices, low_act)
    random_rows = features[0][random_indices, :]
    features[0][random_indices, :] = np.tile(np.array([[0.2]]),random_rows.shape)
    
    
    print("\nMasked {}% of nodes\n".format(int(m*100)))
    prev_loss, op = train(adj,features,labels, random_indices, True)
    #print(op)
    loss, op = train(adj,op.cpu().detach().numpy(),labels, random_indices)
    while loss < prev_loss :
        prev_loss = loss
        loss, op = train(adj,op.cpu().detach().numpy(),labels, random_indices)
# Out:
# Masked 100% of nodes
#
# Epoch: 0001 Accuracy: 0.1779 Loss: 1.61217761 time: 0.3650s
# Epoch: 1001 Accuracy: 0.3365 Loss: 1.57690823 time: 0.0010s
# Epoch: 2001 Accuracy: 0.3462 Loss: 1.54271019 time: 0.0010s
# Epoch: 3001 Accuracy: 0.3462 Loss: 1.53996670 time: 0.0020s
# Epoch: 4001 Accuracy: 0.3510 Loss: 1.53668225 time: 0.0020s
# Epoch: 5001 Accuracy: 0.3510 Loss: 1.53509212 time: 0.0020s
# Epoch: 6001 Accuracy: 0.3510 Loss: 1.53405273 time: 0.0020s
# Epoch: 7001 Accuracy: 0.3510 Loss: 1.52649283 time: 0.0030s
# Epoch: 8001 Accuracy: 0.3462 Loss: 1.51983666 time: 0.0020s
# Epoch: 9001 Accuracy: 0.3462 Loss: 1.51983666 time: 0.0020s
# Epoch: 10001 Accuracy: 0.3462 Loss: 1.51983666 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 18.4815s
# Epoch: 0001 Accuracy: 0.3462 Loss: 1.51983666 time: 0.0030s
# Epoch: 1001 Accuracy: 0.3558 Loss: 1.46526635 time: 0.0020s
# Epoch: 2001 Accuracy: 0.4423 Loss: 1.43479204 time: 0.0020s
# Epoch: 3001 Accuracy: 0.4423 Loss: 1.41708422 time: 0.0030s
# Epoch: 4001 Accuracy: 0.4904 Loss: 1.39255476 time: 0.0031s
# Epoch: 5001 Accuracy: 0.4904 Loss: 1.38682497 time: 0.0020s
# Epoch: 6001 Accuracy: 0.4904 Loss: 1.38682497 time: 0.0020s
# Epoch: 7001 Accuracy: 0.4904 Loss: 1.38682497 time: 0.0010s
# Epoch: 8001 Accuracy: 0.4904 Loss: 1.38682497 time: 0.0020s
# Epoch: 9001 Accuracy: 0.4904 Loss: 1.38682497 time: 0.0020s
# Epoch: 10001 Accuracy: 0.4904 Loss: 1.38682497 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.1760s
# Epoch: 0001 Accuracy: 0.4904 Loss: 1.38682497 time: 0.0020s
# Epoch: 1001 Accuracy: 0.4904 Loss: 1.38033819 time: 0.0020s
# Epoch: 2001 Accuracy: 0.4952 Loss: 1.37548375 time: 0.0020s
# Epoch: 3001 Accuracy: 0.4904 Loss: 1.37065756 time: 0.0020s
# Epoch: 4001 Accuracy: 0.5000 Loss: 1.36488736 time: 0.0020s
# Epoch: 5001 Accuracy: 0.5144 Loss: 1.35902929 time: 0.0020s
# Epoch: 6001 Accuracy: 0.5337 Loss: 1.34756494 time: 0.0020s
# Epoch: 7001 Accuracy: 0.5481 Loss: 1.33381855 time: 0.0020s
# Epoch: 8001 Accuracy: 0.5481 Loss: 1.33381057 time: 0.0020s
# Epoch: 9001 Accuracy: 0.5481 Loss: 1.33381057 time: 0.0030s
# Epoch: 10001 Accuracy: 0.5481 Loss: 1.33381057 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.2675s
# Epoch: 0001 Accuracy: 0.5481 Loss: 1.33381057 time: 0.0020s
# Epoch: 1001 Accuracy: 0.5481 Loss: 1.33056116 time: 0.0020s
# Epoch: 2001 Accuracy: 0.5433 Loss: 1.32747841 time: 0.0020s
# Epoch: 3001 Accuracy: 0.5433 Loss: 1.32437110 time: 0.0020s
# Epoch: 4001 Accuracy: 0.5481 Loss: 1.32083440 time: 0.0020s
# Epoch: 5001 Accuracy: 0.5529 Loss: 1.31747949 time: 0.0020s
# Epoch: 6001 Accuracy: 0.5577 Loss: 1.31467223 time: 0.0020s
# Epoch: 7001 Accuracy: 0.5769 Loss: 1.31037283 time: 0.0030s
# Epoch: 8001 Accuracy: 0.5817 Loss: 1.30321360 time: 0.0030s
# Epoch: 9001 Accuracy: 0.5769 Loss: 1.29914975 time: 0.0020s
# Epoch: 10001 Accuracy: 0.5769 Loss: 1.29914975 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 20.3827s
# Epoch: 0001 Accuracy: 0.5769 Loss: 1.29914975 time: 0.0040s
# Epoch: 1001 Accuracy: 0.5865 Loss: 1.29715729 time: 0.0020s
# Epoch: 2001 Accuracy: 0.5962 Loss: 1.29294157 time: 0.0020s
# Epoch: 3001 Accuracy: 0.5962 Loss: 1.28964543 time: 0.0020s
# Epoch: 4001 Accuracy: 0.5913 Loss: 1.28852022 time: 0.0030s
# Epoch: 5001 Accuracy: 0.5913 Loss: 1.28852022 time: 0.0020s
# Epoch: 6001 Accuracy: 0.5913 Loss: 1.28852022 time: 0.0020s
# Epoch: 7001 Accuracy: 0.5913 Loss: 1.28852022 time: 0.0020s
# Epoch: 8001 Accuracy: 0.5913 Loss: 1.28852022 time: 0.0020s
# Epoch: 9001 Accuracy: 0.5913 Loss: 1.28852022 time: 0.0020s
# Epoch: 10001 Accuracy: 0.5913 Loss: 1.28852022 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.1447s
# Epoch: 0001 Accuracy: 0.5913 Loss: 1.28852022 time: 0.0020s
# Epoch: 1001 Accuracy: 0.5913 Loss: 1.28775764 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6010 Loss: 1.28728557 time: 0.0020s
# Epoch: 3001 Accuracy: 0.5962 Loss: 1.28684068 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6010 Loss: 1.28640854 time: 0.0020s
# Epoch: 5001 Accuracy: 0.5962 Loss: 1.28594542 time: 0.0020s
# Epoch: 6001 Accuracy: 0.5913 Loss: 1.28537571 time: 0.0020s
# Epoch: 7001 Accuracy: 0.5865 Loss: 1.28454924 time: 0.0020s
# Epoch: 8001 Accuracy: 0.5865 Loss: 1.28252983 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6154 Loss: 1.27823901 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6154 Loss: 1.27823901 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 20.2037s
# Epoch: 0001 Accuracy: 0.6154 Loss: 1.27823901 time: 0.0030s
# Epoch: 1001 Accuracy: 0.6154 Loss: 1.27800739 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6154 Loss: 1.27758408 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6154 Loss: 1.27705145 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6154 Loss: 1.27634799 time: 0.0020s
# Epoch: 5001 Accuracy: 0.6154 Loss: 1.27512670 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6154 Loss: 1.27317619 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6106 Loss: 1.26908052 time: 0.0030s
# Epoch: 8001 Accuracy: 0.6202 Loss: 1.26364350 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6202 Loss: 1.26364350 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6202 Loss: 1.26364350 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.5190s
# Epoch: 0001 Accuracy: 0.6202 Loss: 1.26364350 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6250 Loss: 1.26291525 time: 0.0030s
# Epoch: 2001 Accuracy: 0.6298 Loss: 1.26212192 time: 0.0030s
# Epoch: 3001 Accuracy: 0.6298 Loss: 1.26130176 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6298 Loss: 1.26039708 time: 0.0030s
# Epoch: 5001 Accuracy: 0.6250 Loss: 1.25934923 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6346 Loss: 1.25564969 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6394 Loss: 1.25427520 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6346 Loss: 1.25163591 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6298 Loss: 1.25016153 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6298 Loss: 1.25016153 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 20.1421s
# Epoch: 0001 Accuracy: 0.6298 Loss: 1.25016153 time: 0.0030s
# Epoch: 1001 Accuracy: 0.6298 Loss: 1.24988639 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6298 Loss: 1.24972320 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6346 Loss: 1.24950349 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6442 Loss: 1.24860013 time: 0.0020s
# Epoch: 5001 Accuracy: 0.6442 Loss: 1.24588776 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6442 Loss: 1.24588776 time: 0.0030s
# Epoch: 7001 Accuracy: 0.6442 Loss: 1.24588776 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6442 Loss: 1.24588776 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6442 Loss: 1.24588776 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6442 Loss: 1.24588776 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 20.5391s
# Epoch: 0001 Accuracy: 0.6442 Loss: 1.24588776 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6442 Loss: 1.24565327 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6442 Loss: 1.24541473 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6442 Loss: 1.24474084 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6442 Loss: 1.24389017 time: 0.0010s
# Epoch: 5001 Accuracy: 0.6490 Loss: 1.24108100 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6490 Loss: 1.23989928 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6490 Loss: 1.23960042 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6490 Loss: 1.23943496 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6490 Loss: 1.23943496 time: 0.0030s
# Epoch: 10001 Accuracy: 0.6490 Loss: 1.23943496 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 18.9860s
# Epoch: 0001 Accuracy: 0.6490 Loss: 1.23943496 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6490 Loss: 1.23942125 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6490 Loss: 1.23938072 time: 0.0030s
# Epoch: 3001 Accuracy: 0.6490 Loss: 1.23929548 time: 0.0030s
# Epoch: 4001 Accuracy: 0.6490 Loss: 1.23912168 time: 0.0030s
# Epoch: 5001 Accuracy: 0.6490 Loss: 1.23871148 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6490 Loss: 1.23800206 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6538 Loss: 1.23758686 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6538 Loss: 1.23758686 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6538 Loss: 1.23758686 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6538 Loss: 1.23758686 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.7510s
# Epoch: 0001 Accuracy: 0.6538 Loss: 1.23758686 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6538 Loss: 1.23735952 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6538 Loss: 1.23707628 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6538 Loss: 1.23658204 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6538 Loss: 1.23558640 time: 0.0020s
# Epoch: 5001 Accuracy: 0.6538 Loss: 1.23491549 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6538 Loss: 1.23285306 time: 0.0030s
# Epoch: 7001 Accuracy: 0.6538 Loss: 1.23285306 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6538 Loss: 1.23285306 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6538 Loss: 1.23285306 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6538 Loss: 1.23285306 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 19.4096s
# Epoch: 0001 Accuracy: 0.6538 Loss: 1.23285306 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6538 Loss: 1.23213971 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6538 Loss: 1.23102629 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6538 Loss: 1.22962451 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6587 Loss: 1.22910237 time: 0.0030s
# Epoch: 5001 Accuracy: 0.6587 Loss: 1.22832465 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6635 Loss: 1.22799027 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6635 Loss: 1.22799027 time: 0.0030s
# Epoch: 8001 Accuracy: 0.6635 Loss: 1.22799027 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6635 Loss: 1.22799027 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6635 Loss: 1.22799027 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.7175s
# Epoch: 0001 Accuracy: 0.6635 Loss: 1.22799027 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6635 Loss: 1.22740412 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6683 Loss: 1.22674787 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6683 Loss: 1.22609305 time: 0.0030s
# Epoch: 4001 Accuracy: 0.6683 Loss: 1.22522664 time: 0.0020s
# Epoch: 5001 Accuracy: 0.6683 Loss: 1.22432923 time: 0.0019s
# Epoch: 6001 Accuracy: 0.6683 Loss: 1.22325313 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6731 Loss: 1.22005093 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6731 Loss: 1.22005093 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6731 Loss: 1.22005093 time: 0.0030s
# Epoch: 10001 Accuracy: 0.6731 Loss: 1.22005093 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.6858s
# Epoch: 0001 Accuracy: 0.6731 Loss: 1.22005093 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6731 Loss: 1.21970069 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6731 Loss: 1.21919012 time: 0.0030s
# Epoch: 3001 Accuracy: 0.6731 Loss: 1.21798599 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6731 Loss: 1.21785688 time: 0.0020s
# Epoch: 5001 Accuracy: 0.6731 Loss: 1.21769071 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6731 Loss: 1.21746898 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6731 Loss: 1.21687329 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6779 Loss: 1.21183634 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6779 Loss: 1.21171486 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6779 Loss: 1.21148264 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.3332s
# Epoch: 0001 Accuracy: 0.6779 Loss: 1.21148264 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6779 Loss: 1.21147931 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6779 Loss: 1.21147382 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6779 Loss: 1.21146846 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6779 Loss: 1.21146131 time: 0.0030s
# Epoch: 5001 Accuracy: 0.6779 Loss: 1.21144783 time: 0.0030s
# Epoch: 6001 Accuracy: 0.6779 Loss: 1.21143222 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6779 Loss: 1.21140885 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6779 Loss: 1.21136999 time: 0.0030s
# Epoch: 9001 Accuracy: 0.6779 Loss: 1.21129680 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6779 Loss: 1.21123815 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.4809s
# Epoch: 0001 Accuracy: 0.6779 Loss: 1.21123815 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6779 Loss: 1.21123612 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6779 Loss: 1.21123266 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6779 Loss: 1.21122575 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6779 Loss: 1.21121764 time: 0.0020s
# Epoch: 5001 Accuracy: 0.6779 Loss: 1.21120667 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6779 Loss: 1.21119201 time: 0.0019s
# Epoch: 7001 Accuracy: 0.6779 Loss: 1.21117187 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6779 Loss: 1.21114004 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6779 Loss: 1.21109211 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6779 Loss: 1.21109211 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.2181s
# Epoch: 0001 Accuracy: 0.6779 Loss: 1.21109211 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6779 Loss: 1.21109056 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6779 Loss: 1.21108758 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6779 Loss: 1.21108294 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6779 Loss: 1.21107650 time: 0.0020s
# Epoch: 5001 Accuracy: 0.6779 Loss: 1.21106744 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6779 Loss: 1.21105516 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6779 Loss: 1.21103573 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6779 Loss: 1.21099102 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6779 Loss: 1.21099102 time: 0.0030s
# Epoch: 10001 Accuracy: 0.6779 Loss: 1.21099102 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.4320s
# Epoch: 0001 Accuracy: 0.6779 Loss: 1.21099102 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6779 Loss: 1.21098971 time: 0.0010s
# Epoch: 2001 Accuracy: 0.6779 Loss: 1.21098685 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6779 Loss: 1.21098244 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6779 Loss: 1.21097577 time: 0.0020s
# Epoch: 5001 Accuracy: 0.6779 Loss: 1.21096635 time: 0.0010s
# Epoch: 6001 Accuracy: 0.6779 Loss: 1.21095204 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6779 Loss: 1.21092439 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6779 Loss: 1.21089661 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6779 Loss: 1.21089661 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6779 Loss: 1.21089661 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.3082s
# Epoch: 0001 Accuracy: 0.6779 Loss: 1.21089661 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6779 Loss: 1.21089518 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6779 Loss: 1.21089196 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6779 Loss: 1.21088672 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6779 Loss: 1.21087825 time: 0.0020s
# Epoch: 5001 Accuracy: 0.6779 Loss: 1.21086526 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6779 Loss: 1.21084213 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6779 Loss: 1.21079051 time: 0.0030s
# Epoch: 8001 Accuracy: 0.6779 Loss: 1.21079051 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6779 Loss: 1.21079051 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6779 Loss: 1.21079051 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 20.1837s
# Epoch: 0001 Accuracy: 0.6779 Loss: 1.21079051 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6779 Loss: 1.21078873 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6779 Loss: 1.21078527 time: 0.0010s
# Epoch: 3001 Accuracy: 0.6779 Loss: 1.21077895 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6779 Loss: 1.21076834 time: 0.0020s
# Epoch: 5001 Accuracy: 0.6779 Loss: 1.21074939 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6779 Loss: 1.21070969 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6779 Loss: 1.21067250 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6779 Loss: 1.21067250 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6779 Loss: 1.21067250 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6779 Loss: 1.21067250 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 19.6080s
# Epoch: 0001 Accuracy: 0.6779 Loss: 1.21067250 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6779 Loss: 1.21067059 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6779 Loss: 1.21066642 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6779 Loss: 1.21065903 time: 0.0010s
# Epoch: 4001 Accuracy: 0.6779 Loss: 1.21064603 time: 0.0020s
# Epoch: 5001 Accuracy: 0.6779 Loss: 1.21062458 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6779 Loss: 1.21058905 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6779 Loss: 1.21055615 time: 0.0022s
# Epoch: 8001 Accuracy: 0.6779 Loss: 1.21055615 time: 0.0030s
# Epoch: 9001 Accuracy: 0.6779 Loss: 1.21055615 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6779 Loss: 1.21055615 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 17.9987s
# Epoch: 0001 Accuracy: 0.6779 Loss: 1.21055615 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6779 Loss: 1.21055460 time: 0.0030s
# Epoch: 2001 Accuracy: 0.6779 Loss: 1.21055198 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6779 Loss: 1.21054757 time: 0.0010s
# Epoch: 4001 Accuracy: 0.6779 Loss: 1.21054089 time: 0.0010s
# Epoch: 5001 Accuracy: 0.6779 Loss: 1.21053195 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6779 Loss: 1.21052003 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6779 Loss: 1.21050453 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6779 Loss: 1.21048272 time: 0.0030s
# Epoch: 9001 Accuracy: 0.6779 Loss: 1.21044672 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6779 Loss: 1.21034884 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.4957s
# Epoch: 0001 Accuracy: 0.6779 Loss: 1.21034884 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6779 Loss: 1.21034789 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6779 Loss: 1.21034563 time: 0.0030s
# Epoch: 3001 Accuracy: 0.6779 Loss: 1.21034229 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6779 Loss: 1.21026218 time: 0.0020s
# Epoch: 5001 Accuracy: 0.6779 Loss: 1.21017933 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6779 Loss: 1.21006763 time: 0.0020s
# Epoch: 7001 Accuracy: 0.6779 Loss: 1.20987189 time: 0.0030s
# Epoch: 8001 Accuracy: 0.6779 Loss: 1.20932174 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6875 Loss: 1.20148778 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6875 Loss: 1.20148778 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 19.7103s
# Epoch: 0001 Accuracy: 0.6875 Loss: 1.20148766 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6875 Loss: 1.20084798 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6923 Loss: 1.19999695 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6875 Loss: 1.19864511 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6923 Loss: 1.19716334 time: 0.0010s
# Epoch: 5001 Accuracy: 0.6923 Loss: 1.19633317 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6923 Loss: 1.19575262 time: 0.0040s
# Epoch: 7001 Accuracy: 0.6971 Loss: 1.19438696 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6971 Loss: 1.19438696 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6971 Loss: 1.19438696 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6971 Loss: 1.19438696 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 21.6974s
# Epoch: 0001 Accuracy: 0.6971 Loss: 1.19438696 time: 0.0030s
# Epoch: 1001 Accuracy: 0.6971 Loss: 1.19387674 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6971 Loss: 1.19331360 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6971 Loss: 1.19240248 time: 0.0020s
# Epoch: 4001 Accuracy: 0.6971 Loss: 1.19234335 time: 0.0030s
# Epoch: 5001 Accuracy: 0.6971 Loss: 1.19224930 time: 0.0020s
# Epoch: 6001 Accuracy: 0.6971 Loss: 1.19210315 time: 0.0030s
# Epoch: 7001 Accuracy: 0.6971 Loss: 1.19184315 time: 0.0020s
# Epoch: 8001 Accuracy: 0.6971 Loss: 1.19140720 time: 0.0020s
# Epoch: 9001 Accuracy: 0.6971 Loss: 1.19131100 time: 0.0020s
# Epoch: 10001 Accuracy: 0.6971 Loss: 1.19131100 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 20.6740s
# Epoch: 0001 Accuracy: 0.6971 Loss: 1.19131100 time: 0.0020s
# Epoch: 1001 Accuracy: 0.6971 Loss: 1.19129252 time: 0.0020s
# Epoch: 2001 Accuracy: 0.6971 Loss: 1.19123149 time: 0.0020s
# Epoch: 3001 Accuracy: 0.6971 Loss: 1.19105673 time: 0.0030s
# Epoch: 4001 Accuracy: 0.6971 Loss: 1.19025683 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18937349 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18919444 time: 0.0026s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18907082 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18895674 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18888462 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18879139 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 21.4794s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18879139 time: 0.0030s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18862998 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18830884 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18770194 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18752360 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18752170 time: 0.0030s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18752170 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18752170 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18752158 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18751836 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18751383 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 21.4095s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18751383 time: 0.0030s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18751383 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18751383 time: 0.0010s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18751383 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18751359 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18751347 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18751299 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18751252 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18751156 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18750966 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18750596 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 20.5953s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18750596 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18750596 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18750596 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18750596 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18750596 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18750584 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18750560 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18750489 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18750393 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18750262 time: 0.0019s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18749785 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.7018s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18749785 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18749785 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18749785 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18749762 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18749738 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18749702 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18749642 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18749547 time: 0.0030s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18749404 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18749094 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18748462 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.9090s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18748462 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18748462 time: 0.0017s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18748462 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18748450 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18748438 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18748403 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18748367 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18748271 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18748128 time: 0.0021s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18747902 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18747306 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.3646s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18747306 time: 0.0030s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18747306 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18747306 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18747294 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18747282 time: 0.0030s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18747246 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18747211 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18747139 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18747008 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18746793 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18746257 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.8086s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18746257 time: 0.0030s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18746257 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18746257 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18746245 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18746233 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18746197 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18746161 time: 0.0030s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18746090 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18745995 time: 0.0022s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18745780 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18745351 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.9234s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18745351 time: 0.0030s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18745351 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18745351 time: 0.0030s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18745351 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18745327 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18745315 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18745279 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18745232 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18745124 time: 0.0030s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18744969 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18744600 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 20.5741s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18744600 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18744600 time: 0.0010s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18744588 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18744588 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18744576 time: 0.0010s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18744552 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18744540 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18744493 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18744409 time: 0.0030s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18744254 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18743944 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 18.8939s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18743944 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18743944 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18743944 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18743932 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18743920 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18743908 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18743885 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18743849 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18743753 time: 0.0030s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18743658 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18743348 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.1213s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18743348 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18743348 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18743348 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18743348 time: 0.0030s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18743336 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18743324 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18743312 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18743277 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18743205 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18743122 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18742859 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.9774s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18742859 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18742859 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18742859 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18742859 time: 0.0019s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18742859 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18742847 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18742824 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18742788 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18742752 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18742645 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18742442 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 19.7621s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18742442 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18742442 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18742442 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18742430 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18742430 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18742418 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18742406 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18742383 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18742347 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18742263 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18742096 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.0773s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18742096 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18742096 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18742096 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18742096 time: 0.0030s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18742096 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18742096 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18742073 time: 0.0030s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18742061 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18742025 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18741953 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18741822 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 20.1472s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18741822 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18741822 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18741822 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18741822 time: 0.0030s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18741810 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18741810 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18741798 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18741775 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18741751 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18741691 time: 0.0010s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18741584 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 18.8843s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18741584 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18741584 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18741584 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18741584 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18741584 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18741572 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18741560 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18741560 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18741536 time: 0.0030s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18741500 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18741393 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.6777s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18741393 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18741393 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18741393 time: 0.0030s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18741393 time: 0.0022s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18741393 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18741393 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18741381 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18741369 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18741345 time: 0.0030s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18741310 time: 0.0030s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18741226 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.7885s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18741226 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18741226 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18741226 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18741226 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18741226 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18741226 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18741214 time: 0.0010s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18741214 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18741202 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18741179 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18741107 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 18.7557s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18741107 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18741107 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18741107 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18741107 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18741107 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18741107 time: 0.0030s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18741107 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18741107 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18741083 time: 0.0030s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18741071 time: 0.0030s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18741035 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.4294s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18741035 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18741035 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18741035 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18741035 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18741035 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18741024 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18741024 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18741024 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18741024 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18741012 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18740964 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.2956s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18740964 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18740964 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18740964 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18740964 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18740964 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18740964 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18740964 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18740964 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18740964 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18740952 time: 0.0010s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18740940 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.7306s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18740940 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18740940 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18740940 time: 0.0030s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18740940 time: 0.0030s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18740940 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18740940 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18740928 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18740928 time: 0.0010s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18740928 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18740916 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18740916 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.2137s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18740916 time: 0.0030s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18740916 time: 0.0010s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18740916 time: 0.0010s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18740916 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18740916 time: 0.0020s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18740916 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18740916 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18740916 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18740916 time: 0.0030s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18740916 time: 0.0030s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18740904 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 19.3809s
# Epoch: 0001 Accuracy: 0.7019 Loss: 1.18740904 time: 0.0020s
# Epoch: 1001 Accuracy: 0.7019 Loss: 1.18740904 time: 0.0020s
# Epoch: 2001 Accuracy: 0.7019 Loss: 1.18740904 time: 0.0020s
# Epoch: 3001 Accuracy: 0.7019 Loss: 1.18740904 time: 0.0020s
# Epoch: 4001 Accuracy: 0.7019 Loss: 1.18740904 time: 0.0030s
# Epoch: 5001 Accuracy: 0.7019 Loss: 1.18740904 time: 0.0020s
# Epoch: 6001 Accuracy: 0.7019 Loss: 1.18740904 time: 0.0020s
# Epoch: 7001 Accuracy: 0.7019 Loss: 1.18740904 time: 0.0020s
# Epoch: 8001 Accuracy: 0.7019 Loss: 1.18740904 time: 0.0020s
# Epoch: 9001 Accuracy: 0.7019 Loss: 1.18740904 time: 0.0020s
# Epoch: 10001 Accuracy: 0.7019 Loss: 1.18740904 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 20.2830s
